# %%
import pandas as pd
import os
import random
import numpy as np

# %%
data_dir = '/opt/ml/input/data' # 경로는 상황에 맞춰서 수정해주세요!
csv_file_path = os.path.join(data_dir, 'train_data.csv') # 데이터는 대회홈페이지에서 받아주세요 :)
df = pd.read_csv(csv_file_path)

# %% [markdown]
# # 전처리

# %%
def feature_engineering(df):
    
    #유저별 시퀀스를 고려하기 위해 아래와 같이 정렬
    df.sort_values(by=['userID','Timestamp'], inplace=True)
    
    #유저들의 문제 풀이수, 정답 수, 정답률을 시간순으로 누적해서 계산
    df['user_correct_answer'] = df.groupby('userID')['answerCode'].transform(lambda x: x.cumsum().shift(1))
    df['user_total_answer'] = df.groupby('userID')['answerCode'].cumcount()
    df['user_acc'] = df['user_correct_answer']/df['user_total_answer']

    # testId와 KnowledgeTag의 전체 정답률은 한번에 계산
    # 아래 데이터는 제출용 데이터셋에 대해서도 재사용
    correct_t = df.groupby(['testId'])['answerCode'].agg(['mean', 'sum'])
    correct_t.columns = ["test_mean", 'test_sum']
    correct_k = df.groupby(['KnowledgeTag'])['answerCode'].agg(['mean', 'sum'])
    correct_k.columns = ["tag_mean", 'tag_sum']

    df = pd.merge(df, correct_t, on=['testId'], how="left")
    df = pd.merge(df, correct_k, on=['KnowledgeTag'], how="left")
    
    return df

# %%
df = feature_engineering(df)
df.head()
# Out:
#    userID assessmentItemID      testId  answerCode            Timestamp  \
# 0       0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1       0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2       0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3       0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4       0       A060001005  A060000001           1  2020-03-24 00:17:36
#
#    KnowledgeTag  user_correct_answer  user_total_answer  user_acc  test_mean  \
# 0          7224                  NaN                  0       NaN   0.947683
# 1          7225                  1.0                  1       1.0   0.947683
# 2          7225                  2.0                  2       1.0   0.947683
# 3          7225                  3.0                  3       1.0   0.947683
# 4          7225                  4.0                  4       1.0   0.947683
#
#    test_sum  tag_mean  tag_sum
# 0      1268  0.955022      637
# 1      1268  0.913187     3040
# 2      1268  0.913187     3040
# 3      1268  0.913187     3040
# 4      1268  0.913187     3040

# %%
from sklearn.preprocessing import LabelEncoder
import time
from datetime import datetime
asset_dir = '/opt/ml/input/code/'#/asset/'

def preprocessing(df, is_train=True):
    cate_cols = ["assessmentItemID", "testId", "KnowledgeTag"]

    #if not os.path.exists(self.args.asset_dir):
    #     os.makedirs(self.args.asset_dir)

    for col in cate_cols:

        le = LabelEncoder()
        if is_train:
            # For UNKNOWN class
            a = df[col].unique().tolist() + ["unknown"]
            le.fit(a)
            le_path = os.path.join(asset_dir, col + "_classes.npy")
            print(le_path)
            #print(le_path)
            np.save(le_path, le.classes_)
        
        else:
            label_path = os.path.join(asset_dir, col + "_classes.npy")
            print(label_path)
            le.classes_ = np.load(label_path)

            df[col] = df[col].apply(
                lambda x: x if str(x) in le.classes_ else "unknown"
            )

        # 모든 컬럼이 범주형이라고 가정
        df[col] = df[col].astype(str)
        test = le.transform(df[col])
        df[col] = test

    def convert_time(s):
        timestamp = time.mktime(
            datetime.strptime(s, "%Y-%m-%d %H:%M:%S").timetuple()
        )
        return int(timestamp)

    df["Timestamp"] = df["Timestamp"].apply(convert_time)

    return df

# %%
df = preprocessing(df, is_train=True)
# Out:
# /opt/ml/input/code/assessmentItemID_classes.npy
# /opt/ml/input/code/testId_classes.npy
# /opt/ml/input/code/KnowledgeTag_classes.npy

# %%
df = df.sort_values(['userID', 'Timestamp'])

# %%
# diff
df['diff'] = df.sort_values(['userID','Timestamp']).groupby('userID')['Timestamp'].diff()#periods=-1).apply(abs)

diff_df = df['diff']
diff_df.dropna(inplace=True)

# nan은 -1
# 600(10분) 이상이면 다 600
df['diff'].fillna(-1, inplace=True)
idx = df[df['diff'] >= 600].index
df.loc[idx, 'diff'] = 600

# %%
tmp = df[df['diff'] >= 0]
correct_k = tmp.groupby(['KnowledgeTag'])['diff'].agg(['mean'])
df = pd.merge(df, correct_k, on=['KnowledgeTag'], how="left")

# %%
# train과 test 데이터셋은 사용자 별로 묶어서 분리를 해주어야함
random.seed(42)
def custom_train_test_split(df, ratio=0.7, split=True):
    
    users = list(zip(df['userID'].value_counts().index, df['userID'].value_counts()))
    random.shuffle(users)
    
    max_train_data_len = ratio*len(df)
    sum_of_train_data = 0
    user_ids =[]

    for user_id, count in users:
        sum_of_train_data += count
        if max_train_data_len < sum_of_train_data:
            break
        user_ids.append(user_id)


    train = df[df['userID'].isin(user_ids)]
    test = df[df['userID'].isin(user_ids) == False]

    #test데이터셋은 각 유저의 마지막 interaction만 추출
    #test = test[test['userID'] != test['userID'].shift(-1)]
    return train, test

# %%
df
# Out:
#          userID  assessmentItemID  testId  answerCode   Timestamp  \
# 0             0              5354     975           1  1585009031
# 1             0              5355     975           1  1585009034
# 2             0              5356     975           1  1585009042
# 3             0              5357     975           1  1585009049
# 4             0              5358     975           1  1585009056
# ...         ...               ...     ...         ...         ...
# 2266581    7441              2373     456           0  1591339821
# 2266582    7441              3909     748           1  1597971999
# 2266583    7441              3910     748           1  1597972010
# 2266584    7441              3911     748           1  1597972056
# 2266585    7441              3912     748           1  1597972129
#
#          KnowledgeTag  user_correct_answer  user_total_answer  user_acc  \
# 0                 618                  NaN                  0       NaN
# 1                 619                  1.0                  1  1.000000
# 2                 619                  2.0                  2  1.000000
# 3                 619                  3.0                  3  1.000000
# 4                 619                  4.0                  4  1.000000
# ...               ...                  ...                ...       ...
# 2266581           375                  1.0                  4  0.250000
# 2266582           784                  1.0                  5  0.200000
# 2266583           784                  2.0                  6  0.333333
# 2266584           784                  3.0                  7  0.428571
# 2266585           784                  4.0                  8  0.500000
#
#          test_mean  test_sum  tag_mean  tag_sum   diff        mean
# 0         0.947683      1268  0.955022      637   -1.0  345.923228
# 1         0.947683      1268  0.913187     3040    3.0   59.008799
# 2         0.947683      1268  0.913187     3040    8.0   59.008799
# 3         0.947683      1268  0.913187     3040    7.0   59.008799
# 4         0.947683      1268  0.913187     3040    7.0   59.008799
# ...            ...       ...       ...      ...    ...         ...
# 2266581   0.662590       921  0.689706     2814   24.0  160.096973
# 2266582   0.655109       718  0.697874     2199  600.0  162.502079
# 2266583   0.655109       718  0.697874     2199   11.0  162.502079
# 2266584   0.655109       718  0.697874     2199   46.0  162.502079
# 2266585   0.655109       718  0.697874     2199   73.0  162.502079
#
# [2266586 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['userID', 'assessmentItemID', 'testId', 'answerCode', 'Timestamp',
#        'KnowledgeTag', 'user_correct_answer', 'user_total_answer', 'user_acc',
#        'test_mean', 'test_sum', 'tag_mean', 'tag_sum', 'diff', 'mean'],
#       dtype='object')

# %%
# 유저별 분리
train, test = custom_train_test_split(df)

#FEATS = ['userID', 'assessmentItemID', 'testId', 'Timestamp',
#       'KnowledgeTag', 'user_correct_answer', 'user_total_answer', 'user_acc',
#       'test_mean', 'test_sum', 'tag_mean', 'tag_sum', 'diff', 'mean']
# 사용할 Feature 설정
FEATS = ['KnowledgeTag', 'user_correct_answer',
         'user_acc', 'test_mean', 'test_sum', 'tag_mean',
         'assessmentItemID', 'Timestamp', 'diff', 'mean']#, 'tag_sum']

# X, y 값 분리
y_train = train['answerCode']
train = train.drop(['answerCode'], axis=1)
train.fillna(0, axis=1, inplace=True)

y_test = test['answerCode']
test = test.drop(['answerCode'], axis=1)
test.fillna(0, axis=1, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

#diff_scalar = MinMaxScaler()
#train['mean'] = diff_scalar.fit_transform(train['mean'].values.reshape(-1, 1))
#test['mean'] = diff_scalar.transform(test['mean'].values.reshape(-1, 1))

user_total_scaler = MinMaxScaler()
train['user_total_answer'] = user_total_scaler.fit_transform(train['user_total_answer'].values.reshape(-1, 1))
test['user_total_answer'] = user_total_scaler.transform(test['user_total_answer'].values.reshape(-1, 1))

user_correct_scalar = MinMaxScaler()
train['user_correct_answer'] = user_correct_scalar.fit_transform(train['user_correct_answer'].values.reshape(-1, 1))
test['user_correct_answer'] = user_correct_scalar.transform(test['user_correct_answer'].values.reshape(-1, 1))

tmestamp_scalar = MinMaxScaler()
train['Timestamp'] = tmestamp_scalar.fit_transform(train['Timestamp'].values.reshape(-1, 1))
test['Timestamp'] = tmestamp_scalar.transform(test['Timestamp'].values.reshape(-1, 1))

test_sum_scalar = MinMaxScaler()
train['test_sum'] = test_sum_scalar.fit_transform(train['test_sum'].values.reshape(-1, 1))
test['test_sum'] = test_sum_scalar.transform(test['test_sum'].values.reshape(-1, 1))

tag_sum_scalar = MinMaxScaler()
train['tag_sum'] = tag_sum_scalar.fit_transform(train['tag_sum'].values.reshape(-1, 1))
test['tag_sum'] = tag_sum_scalar.transform(test['tag_sum'].values.reshape(-1, 1))

# %% [markdown]
# # 모델링

# %% [markdown]
# ### lightgbm

# %%
import lightgbm as lgb
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
import numpy as np

lgb_train = lgb.Dataset(train[FEATS], y_train)
lgb_test = lgb.Dataset(test[FEATS], y_test)

# %%
def model_train(): 
    model = lgb.train(
        {'objective': 'binary'}, 
        lgb_train,
        valid_sets=[lgb_train, lgb_test],
        verbose_eval=100,
        num_boost_round=2500, #config.num_boost_round,
        early_stopping_rounds=100 #config.early_stopping_rounds
    )

    preds = model.predict(test[FEATS])
    acc = accuracy_score(y_test, np.where(preds >= 0.5, 1, 0))
    auc = roc_auc_score(y_test, preds)

    print(f'VALID AUC : {auc} ACC : {acc}\n')

    return model

# %%
model = model_train()
# Out:
# /opt/conda/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 1039565, number of negative: 546592
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010426 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2547
# [LightGBM] [Info] Number of data points in the train set: 1586157, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.655399 -> initscore=0.642855
# [LightGBM] [Info] Start training from score 0.642855
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.520279	valid_1's binary_logloss: 0.52452
# [200]	training's binary_logloss: 0.516122	valid_1's binary_logloss: 0.52202
# [300]	training's binary_logloss: 0.513424	valid_1's binary_logloss: 0.521018
# [400]	training's binary_logloss: 0.510904	valid_1's binary_logloss: 0.520107
# [500]	training's binary_logloss: 0.508831	valid_1's binary_logloss: 0.519422
# [600]	training's binary_logloss: 0.506856	valid_1's binary_logloss: 0.51886
# [700]	training's binary_logloss: 0.504906	valid_1's binary_logloss: 0.518341
# [800]	training's binary_logloss: 0.503132	valid_1's binary_logloss: 0.517976
# [900]	training's binary_logloss: 0.501485	valid_1's binary_logloss: 0.517813
# [1000]	training's binary_logloss: 0.499946	valid_1's binary_logloss: 0.517529
# [1100]	training's binary_logloss: 0.498503	valid_1's binary_logloss: 0.517371
# [1200]	training's binary_logloss: 0.497055	valid_1's binary_logloss: 0.517166
# [1300]	training's binary_logloss: 0.495645	valid_1's binary_logloss: 0.516947
# [1400]	training's binary_logloss: 0.494249	valid_1's binary_logloss: 0.5168
# [1500]	training's binary_logloss: 0.49295	valid_1's binary_logloss: 0.516609
# [1600]	training's binary_logloss: 0.491578	valid_1's binary_logloss: 0.516499
# [1700]	training's binary_logloss: 0.490404	valid_1's binary_logloss: 0.516402
# [1800]	training's binary_logloss: 0.489109	valid_1's binary_logloss: 0.516279
# [1900]	training's binary_logloss: 0.487891	valid_1's binary_logloss: 0.516232
# [2000]	training's binary_logloss: 0.486637	valid_1's binary_logloss: 0.51617
# [2100]	training's binary_logloss: 0.485416	valid_1's binary_logloss: 0.516114
# [2200]	training's binary_logloss: 0.484152	valid_1's binary_logloss: 0.515946
# [2300]	training's binary_logloss: 0.483061	valid_1's binary_logloss: 0.515953
# Early stopping, best iteration is:
# [2220]	training's binary_logloss: 0.483892	valid_1's binary_logloss: 0.515931
# VALID AUC : 0.7844633271046747 ACC : 0.7557232275520297

# %%
lgbm_train_preds = model.predict(train[FEATS])
lgbm_valid_preds = model.predict(test[FEATS])

# %% [markdown]
# ### xgboost

# %%
import xgboost as xgb
from xgboost import XGBClassifier

params = {
    'learning_rate': 0.1,
    'objective': 'binary:logistic',
    'min_child_weight': 1,
    'eval_metric': 'auc',
    'n_estimators': 800,
    'early_stopping_rounds': 100,
    'max_depth': 12, 
    'max_leaves':5, 
    # 'min_child_weigh'1
    }

xg = XGBClassifier(**params)

xg.fit(train[FEATS], y_train, eval_set=[(test[FEATS], y_test)])
# Out:
# [0]	validation_0-auc:0.76518
# [1]	validation_0-auc:0.76891
# [2]	validation_0-auc:0.77056
# [3]	validation_0-auc:0.77177
# [4]	validation_0-auc:0.77237
# [5]	validation_0-auc:0.77285
# [6]	validation_0-auc:0.77352
# [7]	validation_0-auc:0.77404
# [8]	validation_0-auc:0.77444
# [9]	validation_0-auc:0.77508
# [10]	validation_0-auc:0.77549
# [11]	validation_0-auc:0.77585
# [12]	validation_0-auc:0.77614
# [13]	validation_0-auc:0.77648
# [14]	validation_0-auc:0.77685
# [15]	validation_0-auc:0.77714
# [16]	validation_0-auc:0.77743
# [17]	validation_0-auc:0.77762
# [18]	validation_0-auc:0.77793
# [19]	validation_0-auc:0.77813
# [20]	validation_0-auc:0.77840
# [21]	validation_0-auc:0.77861
# [22]	validation_0-auc:0.77892
# [23]	validation_0-auc:0.77908
# [24]	validation_0-auc:0.77930
# [25]	validation_0-auc:0.77955
# [26]	validation_0-auc:0.77971
# [27]	validation_0-auc:0.77985
# [28]	validation_0-auc:0.77999
# [29]	validation_0-auc:0.78027
# [30]	validation_0-auc:0.78049
# [31]	validation_0-auc:0.78074
# [32]	validation_0-auc:0.78115
# [33]	validation_0-auc:0.78140
# [34]	validation_0-auc:0.78163
# [35]	validation_0-auc:0.78183
# [36]	validation_0-auc:0.78212
# [37]	validation_0-auc:0.78248
# [38]	validation_0-auc:0.78255
# [39]	validation_0-auc:0.78293
# [40]	validation_0-auc:0.78326
# [41]	validation_0-auc:0.78333
# [42]	validation_0-auc:0.78349
# [43]	validation_0-auc:0.78388
# [44]	validation_0-auc:0.78407
# [45]	validation_0-auc:0.78419
# [46]	validation_0-auc:0.78457
# [47]	validation_0-auc:0.78475
# [48]	validation_0-auc:0.78497
# [49]	validation_0-auc:0.78506
# [50]	validation_0-auc:0.78528
# [51]	validation_0-auc:0.78534
# [52]	validation_0-auc:0.78540
# [53]	validation_0-auc:0.78560
# [54]	validation_0-auc:0.78562
# [55]	validation_0-auc:0.78567
# [56]	validation_0-auc:0.78583
# [57]	validation_0-auc:0.78586
# [58]	validation_0-auc:0.78608
# [59]	validation_0-auc:0.78609
# [60]	validation_0-auc:0.78657
# [61]	validation_0-auc:0.78663
# [62]	validation_0-auc:0.78676
# [63]	validation_0-auc:0.78707
# [64]	validation_0-auc:0.78705
# [65]	validation_0-auc:0.78718
# [66]	validation_0-auc:0.78718
# [67]	validation_0-auc:0.78746
# [68]	validation_0-auc:0.78762
# [69]	validation_0-auc:0.78773
# [70]	validation_0-auc:0.78774
# [71]	validation_0-auc:0.78781
# [72]	validation_0-auc:0.78784
# [73]	validation_0-auc:0.78785
# [74]	validation_0-auc:0.78786
# [75]	validation_0-auc:0.78785
# [76]	validation_0-auc:0.78800
# [77]	validation_0-auc:0.78800
# [78]	validation_0-auc:0.78807
# [79]	validation_0-auc:0.78827
# [80]	validation_0-auc:0.78832
# [81]	validation_0-auc:0.78833
# [82]	validation_0-auc:0.78857
# [83]	validation_0-auc:0.78891
# [84]	validation_0-auc:0.78889
# [85]	validation_0-auc:0.78892
# [86]	validation_0-auc:0.78895
# [87]	validation_0-auc:0.78894
# [88]	validation_0-auc:0.78895
# [89]	validation_0-auc:0.78895
# [90]	validation_0-auc:0.78895
# [91]	validation_0-auc:0.78909
# [92]	validation_0-auc:0.78914
# [93]	validation_0-auc:0.78922
# [94]	validation_0-auc:0.78924
# [95]	validation_0-auc:0.78924
# [96]	validation_0-auc:0.78924
# [97]	validation_0-auc:0.78932
# [98]	validation_0-auc:0.78931
# [99]	validation_0-auc:0.78929
# [100]	validation_0-auc:0.78929
# [101]	validation_0-auc:0.78945
# [102]	validation_0-auc:0.78949
# [103]	validation_0-auc:0.78969
# [104]	validation_0-auc:0.78970
# [105]	validation_0-auc:0.78978
# [106]	validation_0-auc:0.78983
# [107]	validation_0-auc:0.78994
# [108]	validation_0-auc:0.79025
# [109]	validation_0-auc:0.79027
# [110]	validation_0-auc:0.79026
# [111]	validation_0-auc:0.79053
# [112]	validation_0-auc:0.79061
# [113]	validation_0-auc:0.79090
# [114]	validation_0-auc:0.79110
# [115]	validation_0-auc:0.79115
# [116]	validation_0-auc:0.79115
# [117]	validation_0-auc:0.79115
# [118]	validation_0-auc:0.79135
# [119]	validation_0-auc:0.79142
# [120]	validation_0-auc:0.79142
# [121]	validation_0-auc:0.79148
# [122]	validation_0-auc:0.79160
# [123]	validation_0-auc:0.79162
# [124]	validation_0-auc:0.79176
# [125]	validation_0-auc:0.79176
# [126]	validation_0-auc:0.79184
# [127]	validation_0-auc:0.79184
# [128]	validation_0-auc:0.79183
# [129]	validation_0-auc:0.79188
# [130]	validation_0-auc:0.79188
# [131]	validation_0-auc:0.79188
# [132]	validation_0-auc:0.79195
# [133]	validation_0-auc:0.79203
# [134]	validation_0-auc:0.79203
# [135]	validation_0-auc:0.79207
# [136]	validation_0-auc:0.79219
# [137]	validation_0-auc:0.79224
# [138]	validation_0-auc:0.79226
# [139]	validation_0-auc:0.79238
# [140]	validation_0-auc:0.79241
# [141]	validation_0-auc:0.79248
# [142]	validation_0-auc:0.79256
# [143]	validation_0-auc:0.79255
# [144]	validation_0-auc:0.79255
# [145]	validation_0-auc:0.79259
# [146]	validation_0-auc:0.79259
# [147]	validation_0-auc:0.79260
# [148]	validation_0-auc:0.79270
# [149]	validation_0-auc:0.79271
# [150]	validation_0-auc:0.79277
# [151]	validation_0-auc:0.79277
# [152]	validation_0-auc:0.79281
# [153]	validation_0-auc:0.79280
# [154]	validation_0-auc:0.79279
# [155]	validation_0-auc:0.79278
# [156]	validation_0-auc:0.79285
# [157]	validation_0-auc:0.79286
# [158]	validation_0-auc:0.79290
# [159]	validation_0-auc:0.79289
# [160]	validation_0-auc:0.79295
# [161]	validation_0-auc:0.79306
# [162]	validation_0-auc:0.79319
# [163]	validation_0-auc:0.79323
# [164]	validation_0-auc:0.79322
# [165]	validation_0-auc:0.79343
# [166]	validation_0-auc:0.79355
# [167]	validation_0-auc:0.79354
# [168]	validation_0-auc:0.79354
# [169]	validation_0-auc:0.79353
# [170]	validation_0-auc:0.79351
# [171]	validation_0-auc:0.79348
# [172]	validation_0-auc:0.79349
# [173]	validation_0-auc:0.79348
# [174]	validation_0-auc:0.79354
# [175]	validation_0-auc:0.79352
# [176]	validation_0-auc:0.79352
# [177]	validation_0-auc:0.79353
# [178]	validation_0-auc:0.79358
# [179]	validation_0-auc:0.79376
# [180]	validation_0-auc:0.79385
# [181]	validation_0-auc:0.79385
# [182]	validation_0-auc:0.79390
# [183]	validation_0-auc:0.79389
# [184]	validation_0-auc:0.79392
# [185]	validation_0-auc:0.79391
# [186]	validation_0-auc:0.79393
# [187]	validation_0-auc:0.79403
# [188]	validation_0-auc:0.79406
# [189]	validation_0-auc:0.79407
# [190]	validation_0-auc:0.79407
# [191]	validation_0-auc:0.79412
# [192]	validation_0-auc:0.79413
# [193]	validation_0-auc:0.79412
# [194]	validation_0-auc:0.79418
# [195]	validation_0-auc:0.79423
# [196]	validation_0-auc:0.79442
# [197]	validation_0-auc:0.79445
# [198]	validation_0-auc:0.79446
# [199]	validation_0-auc:0.79453
# [200]	validation_0-auc:0.79455
# [201]	validation_0-auc:0.79454
# [202]	validation_0-auc:0.79456
# [203]	validation_0-auc:0.79456
# [204]	validation_0-auc:0.79458
# [205]	validation_0-auc:0.79461
# [206]	validation_0-auc:0.79465
# [207]	validation_0-auc:0.79477
# [208]	validation_0-auc:0.79485
# [209]	validation_0-auc:0.79493
# [210]	validation_0-auc:0.79511
# [211]	validation_0-auc:0.79522
# [212]	validation_0-auc:0.79525
# [213]	validation_0-auc:0.79525
# [214]	validation_0-auc:0.79538
# [215]	validation_0-auc:0.79549
# [216]	validation_0-auc:0.79550
# [217]	validation_0-auc:0.79552
# [218]	validation_0-auc:0.79553
# [219]	validation_0-auc:0.79552
# [220]	validation_0-auc:0.79552
# [221]	validation_0-auc:0.79551
# [222]	validation_0-auc:0.79550
# [223]	validation_0-auc:0.79566
# [224]	validation_0-auc:0.79566
# [225]	validation_0-auc:0.79566
# [226]	validation_0-auc:0.79574
# [227]	validation_0-auc:0.79578
# [228]	validation_0-auc:0.79578
# [229]	validation_0-auc:0.79578
# [230]	validation_0-auc:0.79580
# [231]	validation_0-auc:0.79589
# [232]	validation_0-auc:0.79588
# [233]	validation_0-auc:0.79590
# [234]	validation_0-auc:0.79601
# [235]	validation_0-auc:0.79603
# [236]	validation_0-auc:0.79602
# [237]	validation_0-auc:0.79602
# [238]	validation_0-auc:0.79602
# [239]	validation_0-auc:0.79602
# [240]	validation_0-auc:0.79601
# [241]	validation_0-auc:0.79601
# [242]	validation_0-auc:0.79602
# [243]	validation_0-auc:0.79604
# [244]	validation_0-auc:0.79603
# [245]	validation_0-auc:0.79613
# [246]	validation_0-auc:0.79613
# [247]	validation_0-auc:0.79615
# [248]	validation_0-auc:0.79615
# [249]	validation_0-auc:0.79614
# [250]	validation_0-auc:0.79613
# [251]	validation_0-auc:0.79620
# [252]	validation_0-auc:0.79621
# [253]	validation_0-auc:0.79636
# [254]	validation_0-auc:0.79634
# [255]	validation_0-auc:0.79636
# [256]	validation_0-auc:0.79636
# [257]	validation_0-auc:0.79641
# [258]	validation_0-auc:0.79641
# [259]	validation_0-auc:0.79640
# [260]	validation_0-auc:0.79654
# [261]	validation_0-auc:0.79658
# [262]	validation_0-auc:0.79663
# [263]	validation_0-auc:0.79668
# [264]	validation_0-auc:0.79673
# [265]	validation_0-auc:0.79672
# [266]	validation_0-auc:0.79680
# [267]	validation_0-auc:0.79680
# [268]	validation_0-auc:0.79682
# [269]	validation_0-auc:0.79681
# [270]	validation_0-auc:0.79685
# [271]	validation_0-auc:0.79684
# [272]	validation_0-auc:0.79684
# [273]	validation_0-auc:0.79684
# [274]	validation_0-auc:0.79684
# [275]	validation_0-auc:0.79687
# [276]	validation_0-auc:0.79686
# [277]	validation_0-auc:0.79685
# [278]	validation_0-auc:0.79694
# [279]	validation_0-auc:0.79697
# [280]	validation_0-auc:0.79696
# [281]	validation_0-auc:0.79696
# [282]	validation_0-auc:0.79695
# [283]	validation_0-auc:0.79699
# [284]	validation_0-auc:0.79699
# [285]	validation_0-auc:0.79700
# [286]	validation_0-auc:0.79702
# [287]	validation_0-auc:0.79702
# [288]	validation_0-auc:0.79704
# [289]	validation_0-auc:0.79705
# [290]	validation_0-auc:0.79708
# [291]	validation_0-auc:0.79707
# [292]	validation_0-auc:0.79707
# [293]	validation_0-auc:0.79709
# [294]	validation_0-auc:0.79709
# [295]	validation_0-auc:0.79714
# [296]	validation_0-auc:0.79720
# [297]	validation_0-auc:0.79718
# [298]	validation_0-auc:0.79718
# [299]	validation_0-auc:0.79718
# [300]	validation_0-auc:0.79718
# [301]	validation_0-auc:0.79723
# [302]	validation_0-auc:0.79732
# [303]	validation_0-auc:0.79733
# [304]	validation_0-auc:0.79733
# [305]	validation_0-auc:0.79732
# [306]	validation_0-auc:0.79736
# [307]	validation_0-auc:0.79740
# [308]	validation_0-auc:0.79739
# [309]	validation_0-auc:0.79739
# [310]	validation_0-auc:0.79740
# [311]	validation_0-auc:0.79745
# [312]	validation_0-auc:0.79746
# [313]	validation_0-auc:0.79746
# [314]	validation_0-auc:0.79749
# [315]	validation_0-auc:0.79747
# [316]	validation_0-auc:0.79745
# [317]	validation_0-auc:0.79754
# [318]	validation_0-auc:0.79755
# [319]	validation_0-auc:0.79753
# [320]	validation_0-auc:0.79752
# [321]	validation_0-auc:0.79754
# [322]	validation_0-auc:0.79754
# [323]	validation_0-auc:0.79752
# [324]	validation_0-auc:0.79754
# [325]	validation_0-auc:0.79753
# [326]	validation_0-auc:0.79752
# [327]	validation_0-auc:0.79759
# [328]	validation_0-auc:0.79762
# [329]	validation_0-auc:0.79761
# [330]	validation_0-auc:0.79763
# [331]	validation_0-auc:0.79764
# [332]	validation_0-auc:0.79772
# [333]	validation_0-auc:0.79771
# [334]	validation_0-auc:0.79772
# [335]	validation_0-auc:0.79774
# [336]	validation_0-auc:0.79775
# [337]	validation_0-auc:0.79774
# [338]	validation_0-auc:0.79780
# [339]	validation_0-auc:0.79779
# [340]	validation_0-auc:0.79782
# [341]	validation_0-auc:0.79792
# [342]	validation_0-auc:0.79794
# [343]	validation_0-auc:0.79794
# [344]	validation_0-auc:0.79793
# [345]	validation_0-auc:0.79793
# [346]	validation_0-auc:0.79790
# [347]	validation_0-auc:0.79791
# [348]	validation_0-auc:0.79792
# [349]	validation_0-auc:0.79794
# [350]	validation_0-auc:0.79800
# [351]	validation_0-auc:0.79801
# [352]	validation_0-auc:0.79800
# [353]	validation_0-auc:0.79806
# [354]	validation_0-auc:0.79807
# [355]	validation_0-auc:0.79806
# [356]	validation_0-auc:0.79805
# [357]	validation_0-auc:0.79807
# [358]	validation_0-auc:0.79804
# [359]	validation_0-auc:0.79804
# [360]	validation_0-auc:0.79804
# [361]	validation_0-auc:0.79804
# [362]	validation_0-auc:0.79806
# [363]	validation_0-auc:0.79808
# [364]	validation_0-auc:0.79812
# [365]	validation_0-auc:0.79812
# [366]	validation_0-auc:0.79812
# [367]	validation_0-auc:0.79812
# [368]	validation_0-auc:0.79812
# [369]	validation_0-auc:0.79812
# [370]	validation_0-auc:0.79811
# [371]	validation_0-auc:0.79814
# [372]	validation_0-auc:0.79815
# [373]	validation_0-auc:0.79815
# [374]	validation_0-auc:0.79814
# [375]	validation_0-auc:0.79813
# [376]	validation_0-auc:0.79814
# [377]	validation_0-auc:0.79813
# [378]	validation_0-auc:0.79812
# [379]	validation_0-auc:0.79813
# [380]	validation_0-auc:0.79813
# [381]	validation_0-auc:0.79813
# [382]	validation_0-auc:0.79813
# [383]	validation_0-auc:0.79815
# [384]	validation_0-auc:0.79815
# [385]	validation_0-auc:0.79816
# [386]	validation_0-auc:0.79816
# [387]	validation_0-auc:0.79816
# [388]	validation_0-auc:0.79815
# [389]	validation_0-auc:0.79816
# [390]	validation_0-auc:0.79815
# [391]	validation_0-auc:0.79816
# [392]	validation_0-auc:0.79813
# [393]	validation_0-auc:0.79813
# [394]	validation_0-auc:0.79814
# [395]	validation_0-auc:0.79820
# [396]	validation_0-auc:0.79821
# [397]	validation_0-auc:0.79819
# [398]	validation_0-auc:0.79819
# [399]	validation_0-auc:0.79819
# [400]	validation_0-auc:0.79818
# [401]	validation_0-auc:0.79821
# [402]	validation_0-auc:0.79821
# [403]	validation_0-auc:0.79821
# [404]	validation_0-auc:0.79825
# [405]	validation_0-auc:0.79825
# [406]	validation_0-auc:0.79825
# [407]	validation_0-auc:0.79825
# [408]	validation_0-auc:0.79828
# [409]	validation_0-auc:0.79829
# [410]	validation_0-auc:0.79834
# [411]	validation_0-auc:0.79847
# [412]	validation_0-auc:0.79850
# [413]	validation_0-auc:0.79851
# [414]	validation_0-auc:0.79848
# [415]	validation_0-auc:0.79848
# [416]	validation_0-auc:0.79851
# [417]	validation_0-auc:0.79855
# [418]	validation_0-auc:0.79855
# [419]	validation_0-auc:0.79854
# [420]	validation_0-auc:0.79854
# [421]	validation_0-auc:0.79859
# [422]	validation_0-auc:0.79867
# [423]	validation_0-auc:0.79866
# [424]	validation_0-auc:0.79872
# [425]	validation_0-auc:0.79871
# [426]	validation_0-auc:0.79874
# [427]	validation_0-auc:0.79874
# [428]	validation_0-auc:0.79884
# [429]	validation_0-auc:0.79889
# [430]	validation_0-auc:0.79888
# [431]	validation_0-auc:0.79889
# [432]	validation_0-auc:0.79889
# [433]	validation_0-auc:0.79888
# [434]	validation_0-auc:0.79888
# [435]	validation_0-auc:0.79888
# [436]	validation_0-auc:0.79898
# [437]	validation_0-auc:0.79900
# [438]	validation_0-auc:0.79899
# [439]	validation_0-auc:0.79900
# [440]	validation_0-auc:0.79899
# [441]	validation_0-auc:0.79897
# [442]	validation_0-auc:0.79899
# [443]	validation_0-auc:0.79904
# [444]	validation_0-auc:0.79904
# [445]	validation_0-auc:0.79903
# [446]	validation_0-auc:0.79902
# [447]	validation_0-auc:0.79905
# [448]	validation_0-auc:0.79908
# [449]	validation_0-auc:0.79907
# [450]	validation_0-auc:0.79908
# [451]	validation_0-auc:0.79911
# [452]	validation_0-auc:0.79911
# [453]	validation_0-auc:0.79911
# [454]	validation_0-auc:0.79912
# [455]	validation_0-auc:0.79912
# [456]	validation_0-auc:0.79916
# [457]	validation_0-auc:0.79916
# [458]	validation_0-auc:0.79916
# [459]	validation_0-auc:0.79914
# [460]	validation_0-auc:0.79913
# [461]	validation_0-auc:0.79914
# [462]	validation_0-auc:0.79915
# [463]	validation_0-auc:0.79916
# [464]	validation_0-auc:0.79914
# [465]	validation_0-auc:0.79915
# [466]	validation_0-auc:0.79914
# [467]	validation_0-auc:0.79914
# [468]	validation_0-auc:0.79917
# [469]	validation_0-auc:0.79925
# [470]	validation_0-auc:0.79939
# [471]	validation_0-auc:0.79942
# [472]	validation_0-auc:0.79942
# [473]	validation_0-auc:0.79941
# [474]	validation_0-auc:0.79940
# [475]	validation_0-auc:0.79942
# [476]	validation_0-auc:0.79944
# [477]	validation_0-auc:0.79941
# [478]	validation_0-auc:0.79940
# [479]	validation_0-auc:0.79946
# [480]	validation_0-auc:0.79947
# [481]	validation_0-auc:0.79947
# [482]	validation_0-auc:0.79951
# [483]	validation_0-auc:0.79952
# [484]	validation_0-auc:0.79953
# [485]	validation_0-auc:0.79953
# [486]	validation_0-auc:0.79954
# [487]	validation_0-auc:0.79954
# [488]	validation_0-auc:0.79953
# [489]	validation_0-auc:0.79950
# [490]	validation_0-auc:0.79950
# [491]	validation_0-auc:0.79949
# [492]	validation_0-auc:0.79955
# [493]	validation_0-auc:0.79958
# [494]	validation_0-auc:0.79957
# [495]	validation_0-auc:0.79966
# [496]	validation_0-auc:0.79965
# [497]	validation_0-auc:0.79965
# [498]	validation_0-auc:0.79962
# [499]	validation_0-auc:0.79962
# [500]	validation_0-auc:0.79963
# [501]	validation_0-auc:0.79963
# [502]	validation_0-auc:0.79964
# [503]	validation_0-auc:0.79970
# [504]	validation_0-auc:0.79972
# [505]	validation_0-auc:0.79972
# [506]	validation_0-auc:0.79972
# [507]	validation_0-auc:0.79972
# [508]	validation_0-auc:0.79972
# [509]	validation_0-auc:0.79972
# [510]	validation_0-auc:0.79972
# [511]	validation_0-auc:0.79972
# [512]	validation_0-auc:0.79971
# [513]	validation_0-auc:0.79971
# [514]	validation_0-auc:0.79970
# [515]	validation_0-auc:0.79969
# [516]	validation_0-auc:0.79978
# [517]	validation_0-auc:0.79978
# [518]	validation_0-auc:0.79976
# [519]	validation_0-auc:0.79975
# [520]	validation_0-auc:0.79975
# [521]	validation_0-auc:0.79982
# [522]	validation_0-auc:0.79989
# [523]	validation_0-auc:0.80003
# [524]	validation_0-auc:0.80003
# [525]	validation_0-auc:0.80002
# [526]	validation_0-auc:0.80006
# [527]	validation_0-auc:0.80009
# [528]	validation_0-auc:0.80012
# [529]	validation_0-auc:0.80012
# [530]	validation_0-auc:0.80012
# [531]	validation_0-auc:0.80011
# [532]	validation_0-auc:0.80015
# [533]	validation_0-auc:0.80016
# [534]	validation_0-auc:0.80015
# [535]	validation_0-auc:0.80015
# [536]	validation_0-auc:0.80014
# [537]	validation_0-auc:0.80016
# [538]	validation_0-auc:0.80015
# [539]	validation_0-auc:0.80017
# [540]	validation_0-auc:0.80020
# [541]	validation_0-auc:0.80020
# [542]	validation_0-auc:0.80022
# [543]	validation_0-auc:0.80027
# [544]	validation_0-auc:0.80027
# [545]	validation_0-auc:0.80029
# [546]	validation_0-auc:0.80029
# [547]	validation_0-auc:0.80033
# [548]	validation_0-auc:0.80033
# [549]	validation_0-auc:0.80035
# [550]	validation_0-auc:0.80035
# [551]	validation_0-auc:0.80034
# [552]	validation_0-auc:0.80034
# [553]	validation_0-auc:0.80033
# [554]	validation_0-auc:0.80038
# [555]	validation_0-auc:0.80042
# [556]	validation_0-auc:0.80047
# [557]	validation_0-auc:0.80045
# [558]	validation_0-auc:0.80046
# [559]	validation_0-auc:0.80046
# [560]	validation_0-auc:0.80045
# [561]	validation_0-auc:0.80045
# [562]	validation_0-auc:0.80044
# [563]	validation_0-auc:0.80044
# [564]	validation_0-auc:0.80044
# [565]	validation_0-auc:0.80046
# [566]	validation_0-auc:0.80047
# [567]	validation_0-auc:0.80050
# [568]	validation_0-auc:0.80049
# [569]	validation_0-auc:0.80049
# [570]	validation_0-auc:0.80048
# [571]	validation_0-auc:0.80048
# [572]	validation_0-auc:0.80048
# [573]	validation_0-auc:0.80048
# [574]	validation_0-auc:0.80047
# [575]	validation_0-auc:0.80048
# [576]	validation_0-auc:0.80047
# [577]	validation_0-auc:0.80046
# [578]	validation_0-auc:0.80051
# [579]	validation_0-auc:0.80053
# [580]	validation_0-auc:0.80051
# [581]	validation_0-auc:0.80055
# [582]	validation_0-auc:0.80057
# [583]	validation_0-auc:0.80057
# [584]	validation_0-auc:0.80056
# [585]	validation_0-auc:0.80060
# [586]	validation_0-auc:0.80059
# [587]	validation_0-auc:0.80059
# [588]	validation_0-auc:0.80058
# [589]	validation_0-auc:0.80058
# [590]	validation_0-auc:0.80058
# [591]	validation_0-auc:0.80058
# [592]	validation_0-auc:0.80058
# [593]	validation_0-auc:0.80057
# [594]	validation_0-auc:0.80060
# [595]	validation_0-auc:0.80060
# [596]	validation_0-auc:0.80060
# [597]	validation_0-auc:0.80063
# [598]	validation_0-auc:0.80063
# [599]	validation_0-auc:0.80062
# [600]	validation_0-auc:0.80067
# [601]	validation_0-auc:0.80067
# [602]	validation_0-auc:0.80066
# [603]	validation_0-auc:0.80066
# [604]	validation_0-auc:0.80070
# [605]	validation_0-auc:0.80078
# [606]	validation_0-auc:0.80080
# [607]	validation_0-auc:0.80079
# [608]	validation_0-auc:0.80079
# [609]	validation_0-auc:0.80083
# [610]	validation_0-auc:0.80084
# [611]	validation_0-auc:0.80087
# [612]	validation_0-auc:0.80087
# [613]	validation_0-auc:0.80087
# [614]	validation_0-auc:0.80086
# [615]	validation_0-auc:0.80088
# [616]	validation_0-auc:0.80093
# [617]	validation_0-auc:0.80093
# [618]	validation_0-auc:0.80093
# [619]	validation_0-auc:0.80092
# [620]	validation_0-auc:0.80093
# [621]	validation_0-auc:0.80092
# [622]	validation_0-auc:0.80092
# [623]	validation_0-auc:0.80091
# [624]	validation_0-auc:0.80091
# [625]	validation_0-auc:0.80091
# [626]	validation_0-auc:0.80092
# [627]	validation_0-auc:0.80093
# [628]	validation_0-auc:0.80094
# [629]	validation_0-auc:0.80094
# [630]	validation_0-auc:0.80094
# [631]	validation_0-auc:0.80094
# [632]	validation_0-auc:0.80093
# [633]	validation_0-auc:0.80093
# [634]	validation_0-auc:0.80092
# [635]	validation_0-auc:0.80094
# [636]	validation_0-auc:0.80102
# [637]	validation_0-auc:0.80100
# [638]	validation_0-auc:0.80105
# [639]	validation_0-auc:0.80105
# [640]	validation_0-auc:0.80110
# [641]	validation_0-auc:0.80111
# [642]	validation_0-auc:0.80110
# [643]	validation_0-auc:0.80110
# [644]	validation_0-auc:0.80109
# [645]	validation_0-auc:0.80109
# [646]	validation_0-auc:0.80108
# [647]	validation_0-auc:0.80108
# [648]	validation_0-auc:0.80109
# [649]	validation_0-auc:0.80110
# [650]	validation_0-auc:0.80110
# [651]	validation_0-auc:0.80110
# [652]	validation_0-auc:0.80109
# [653]	validation_0-auc:0.80116
# [654]	validation_0-auc:0.80116
# [655]	validation_0-auc:0.80116
# [656]	validation_0-auc:0.80119
# [657]	validation_0-auc:0.80119
# [658]	validation_0-auc:0.80119
# [659]	validation_0-auc:0.80118
# [660]	validation_0-auc:0.80119
# [661]	validation_0-auc:0.80119
# [662]	validation_0-auc:0.80119
# [663]	validation_0-auc:0.80120
# [664]	validation_0-auc:0.80123
# [665]	validation_0-auc:0.80123
# [666]	validation_0-auc:0.80125
# [667]	validation_0-auc:0.80129
# [668]	validation_0-auc:0.80129
# [669]	validation_0-auc:0.80129
# [670]	validation_0-auc:0.80129
# [671]	validation_0-auc:0.80130
# [672]	validation_0-auc:0.80131
# [673]	validation_0-auc:0.80132
# [674]	validation_0-auc:0.80135
# [675]	validation_0-auc:0.80136
# [676]	validation_0-auc:0.80137
# [677]	validation_0-auc:0.80138
# [678]	validation_0-auc:0.80141
# [679]	validation_0-auc:0.80144
# [680]	validation_0-auc:0.80143
# [681]	validation_0-auc:0.80145
# [682]	validation_0-auc:0.80146
# [683]	validation_0-auc:0.80147
# [684]	validation_0-auc:0.80148
# [685]	validation_0-auc:0.80149
# [686]	validation_0-auc:0.80148
# [687]	validation_0-auc:0.80149
# [688]	validation_0-auc:0.80149
# [689]	validation_0-auc:0.80149
# [690]	validation_0-auc:0.80149
# [691]	validation_0-auc:0.80149
# [692]	validation_0-auc:0.80149
# [693]	validation_0-auc:0.80148
# [694]	validation_0-auc:0.80148
# [695]	validation_0-auc:0.80149
# [696]	validation_0-auc:0.80150
# [697]	validation_0-auc:0.80152
# [698]	validation_0-auc:0.80152
# [699]	validation_0-auc:0.80154
# [700]	validation_0-auc:0.80155
# [701]	validation_0-auc:0.80155
# [702]	validation_0-auc:0.80154
# [703]	validation_0-auc:0.80161
# [704]	validation_0-auc:0.80161
# [705]	validation_0-auc:0.80161
# [706]	validation_0-auc:0.80160
# [707]	validation_0-auc:0.80162
# [708]	validation_0-auc:0.80164
# [709]	validation_0-auc:0.80165
# [710]	validation_0-auc:0.80169
# [711]	validation_0-auc:0.80168
# [712]	validation_0-auc:0.80175
# [713]	validation_0-auc:0.80174
# [714]	validation_0-auc:0.80174
# [715]	validation_0-auc:0.80173
# [716]	validation_0-auc:0.80176
# [717]	validation_0-auc:0.80174
# [718]	validation_0-auc:0.80176
# [719]	validation_0-auc:0.80175
# [720]	validation_0-auc:0.80175
# [721]	validation_0-auc:0.80175
# [722]	validation_0-auc:0.80175
# [723]	validation_0-auc:0.80174
# [724]	validation_0-auc:0.80175
# [725]	validation_0-auc:0.80175
# [726]	validation_0-auc:0.80177
# [727]	validation_0-auc:0.80177
# [728]	validation_0-auc:0.80177
# [729]	validation_0-auc:0.80175
# [730]	validation_0-auc:0.80174
# [731]	validation_0-auc:0.80177
# [732]	validation_0-auc:0.80178
# [733]	validation_0-auc:0.80179
# [734]	validation_0-auc:0.80182
# [735]	validation_0-auc:0.80181
# [736]	validation_0-auc:0.80181
# [737]	validation_0-auc:0.80181
# [738]	validation_0-auc:0.80182
# [739]	validation_0-auc:0.80182
# [740]	validation_0-auc:0.80182
# [741]	validation_0-auc:0.80182
# [742]	validation_0-auc:0.80181
# [743]	validation_0-auc:0.80187
# [744]	validation_0-auc:0.80187
# [745]	validation_0-auc:0.80186
# [746]	validation_0-auc:0.80185
# [747]	validation_0-auc:0.80185
# [748]	validation_0-auc:0.80185
# [749]	validation_0-auc:0.80184
# [750]	validation_0-auc:0.80184
# [751]	validation_0-auc:0.80183
# [752]	validation_0-auc:0.80182
# [753]	validation_0-auc:0.80185
# [754]	validation_0-auc:0.80186
# [755]	validation_0-auc:0.80186
# [756]	validation_0-auc:0.80185
# [757]	validation_0-auc:0.80187
# [758]	validation_0-auc:0.80190
# [759]	validation_0-auc:0.80192
# [760]	validation_0-auc:0.80194
# [761]	validation_0-auc:0.80193
# [762]	validation_0-auc:0.80194
# [763]	validation_0-auc:0.80197
# [764]	validation_0-auc:0.80197
# [765]	validation_0-auc:0.80197
# [766]	validation_0-auc:0.80196
# [767]	validation_0-auc:0.80194
# [768]	validation_0-auc:0.80193
# [769]	validation_0-auc:0.80191
# [770]	validation_0-auc:0.80195
# [771]	validation_0-auc:0.80194
# [772]	validation_0-auc:0.80195
# [773]	validation_0-auc:0.80194
# [774]	validation_0-auc:0.80193
# [775]	validation_0-auc:0.80193
# [776]	validation_0-auc:0.80193
# [777]	validation_0-auc:0.80194
# [778]	validation_0-auc:0.80194
# [779]	validation_0-auc:0.80193
# [780]	validation_0-auc:0.80193
# [781]	validation_0-auc:0.80193
# [782]	validation_0-auc:0.80192
# [783]	validation_0-auc:0.80193
# [784]	validation_0-auc:0.80193
# [785]	validation_0-auc:0.80192
# [786]	validation_0-auc:0.80194
# [787]	validation_0-auc:0.80194
# [788]	validation_0-auc:0.80193
# [789]	validation_0-auc:0.80192
# [790]	validation_0-auc:0.80194
# [791]	validation_0-auc:0.80195
# [792]	validation_0-auc:0.80195
# [793]	validation_0-auc:0.80198
# [794]	validation_0-auc:0.80199
# [795]	validation_0-auc:0.80198
# [796]	validation_0-auc:0.80201
# [797]	validation_0-auc:0.80201
# [798]	validation_0-auc:0.80200
# [799]	validation_0-auc:0.80200
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=100, enable_categorical=False,
#               eval_metric='auc', gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=12, max_leaves=5, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=800,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
xg_train_preds = xg.predict_proba(train[FEATS])
xg_valid_preds = xg.predict_proba(test[FEATS])

# %% [markdown]
# # 앙상블

# %%
# 단독모델 성능
lgbm_train_acc = accuracy_score(y_train, np.where(lgbm_train_preds >= 0.5, 1, 0))
lgbm_train_auc = roc_auc_score(y_train, lgbm_train_preds)

lgbm_valid_acc = accuracy_score(y_test, np.where(lgbm_valid_preds >= 0.5, 1, 0))
lgbm_valid_auc = roc_auc_score(y_test, lgbm_valid_preds)

xg_train_preds = xg_train_preds[:,-1]
xg_valid_preds = xg_valid_preds[:,-1]
xgboost_train_acc = accuracy_score(y_train, np.where(xg_train_preds >= 0.5, 1, 0))
xgboost_train_auc = roc_auc_score(y_train, xg_train_preds)

xgboost_valid_acc = accuracy_score(y_test, np.where(xg_valid_preds >= 0.5, 1, 0))
xgboost_valid_auc = roc_auc_score(y_test, xg_valid_preds)

# %%
# 메타러닝
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

ensem_train = pd.DataFrame()
ensem_train['lgbm'] = lgbm_train_preds
ensem_train['xg'] =  xg_train_preds

#meta_model = LogisticRegression()
meta_model = GaussianNB()
#meta_model = DecisionTreeClassifier()
meta_model.fit(ensem_train, y_train)

meta_train_pred = meta_model.predict_proba(ensem_train)

meta_train_pred = meta_train_pred[:,-1]
meta_train_acc = accuracy_score(y_train, np.where(meta_train_pred >= 0.5, 1, 0))
meta_train_auc = roc_auc_score(y_train, meta_train_pred)

## valid
ensem_valid = pd.DataFrame()
ensem_valid['lgbm'] = lgbm_valid_preds
ensem_valid['xg'] =  xg_valid_preds

meta_valid_pred = meta_model.predict_proba(ensem_valid)
meta_valid_pred = meta_valid_pred[:,-1]
meta_valid_acc = accuracy_score(y_test, np.where(meta_valid_pred >= 0.5, 1, 0))
meta_valid_auc = roc_auc_score(y_test, meta_valid_pred)

# %%
# 앙상블 기존 방법: 가중 합
train_ensem_5 = (ensem_train.lgbm + ensem_train.xg)/2
ensem_5_train_acc = accuracy_score(y_train, np.where(train_ensem_5 >= 0.5, 1, 0))
ensem_5_train_auc = roc_auc_score(y_train, train_ensem_5)

valid_ensem_5 = (ensem_valid.lgbm + ensem_valid.xg)/2
ensem_5_valid_acc = accuracy_score(y_test, np.where(valid_ensem_5 >= 0.5, 1, 0))
ensem_5_valid_auc = roc_auc_score(y_test, valid_ensem_5)

# %%
print(f'TRAIN LGBM AUC : {lgbm_train_auc} ACC : {lgbm_train_acc}')
print(f'VALID LGBM AUC : {lgbm_valid_auc} ACC : {lgbm_valid_acc}\n')

print(f'TRAIN XGBOOST AUC : {xgboost_train_auc} ACC : {xgboost_train_acc}')
print(f'VALID XGBOOST AUC : {xgboost_valid_auc} ACC : {xgboost_valid_acc}\n')

print(f'TRAIN META AUC : {meta_train_auc} ACC : {meta_train_acc}')
print(f'VALID META AUC : {meta_valid_auc} ACC : {meta_valid_acc}\n')

print(f'TRAIN ENSEM_5 AUC : {ensem_5_train_auc} ACC : {ensem_5_train_acc}')
print(f'VALID ENSEM_5 AUC : {ensem_5_valid_auc} ACC : {ensem_5_valid_acc}')
# Out:
# TRAIN LGBM AUC : 0.817897566425905 ACC : 0.7726360000933072
# VALID LGBM AUC : 0.7844633271046747 ACC : 0.7557232275520297
#
# TRAIN XGBOOST AUC : 0.9089044442253097 ACC : 0.8274180929126184
# VALID XGBOOST AUC : 0.8020092042657967 ACC : 0.7642310953824719
#
# TRAIN META AUC : 0.886815593222321 ACC : 0.8169140885801343
# VALID META AUC : 0.8003611384783527 ACC : 0.7619707566843859
#
# TRAIN ENSEM_5 AUC : 0.876101012354168 ACC : 0.8004857022350247
# VALID ENSEM_5 AUC : 0.7986952096820791 ACC : 0.7620736329580309

# %% [markdown]
# # Inference

# %%
# LOAD TESTDATA
test_csv_file_path = os.path.join(data_dir, 'test_data.csv')
test_df = pd.read_csv(test_csv_file_path)

# FEATURE ENGINEERING
test_df = feature_engineering(test_df)
test_df = preprocessing(test_df, is_train=False)

test_df = test_df.sort_values(['userID', 'Timestamp'])

# diff: nan은 -1 , 600(10분) 이상이면 다 600
test_df['diff'] = test_df.sort_values(['userID','Timestamp']).groupby('userID')['Timestamp'].diff()#periods=-1).apply(abs)
test_df['diff'].fillna(-1, inplace=True)
idx = test_df[test_df['diff'] >= 600].index
test_df.loc[idx, 'diff'] = 600

tmp = test_df[test_df['diff'] >= 0]
correct_k = tmp.groupby(['KnowledgeTag'])['diff'].agg(['mean'])
test_df = pd.merge(test_df, correct_k, on=['KnowledgeTag'], how="left")

# min max scalar
#test_df['mean'] = diff_scalar.transform(test_df['mean'].values.reshape(-1, 1))
test_df['user_total_answer'] = user_total_scaler.transform(test_df['user_total_answer'].values.reshape(-1, 1))
test_df['user_correct_answer'] = user_correct_scalar.transform(test_df['user_correct_answer'].values.reshape(-1, 1))
test_df['Timestamp'] = tmestamp_scalar.transform(test_df['Timestamp'].values.reshape(-1, 1))
test_df['test_sum'] = test_sum_scalar.transform(test_df['test_sum'].values.reshape(-1, 1))
test_df['tag_sum'] = tag_sum_scalar.transform(test_df['tag_sum'].values.reshape(-1, 1))

# LEAVE LAST INTERACTION ONLY
test_df = test_df[test_df['userID'] != test_df['userID'].shift(-1)]

# DROP ANSWERCODE
test_df = test_df.drop(['answerCode'], axis=1)
test_df.fillna(0, axis=1, inplace=True)
# Out:
# /opt/ml/input/code/assessmentItemID_classes.npy
# /opt/ml/input/code/testId_classes.npy
# /opt/ml/input/code/KnowledgeTag_classes.npy

# %%
lgbm_test_preds = model.predict(test_df[FEATS])
xg_test_preds = xg.predict_proba(test_df[FEATS])
xg_test_preds = xg_test_preds[:,-1]

## valid
ensem_test = pd.DataFrame()
ensem_test['lgbm'] = lgbm_test_preds
ensem_test['xg'] =  xg_test_preds

meta_test_pred = meta_model.predict_proba(ensem_test)
meta_test_pred = meta_test_pred[:,-1]

# %%
# SAVE OUTPUT
output_dir = 'output/lgbm/'
write_path = os.path.join(output_dir, "meta_xg_lgbm.csv")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
with open(write_path, 'w', encoding='utf8') as w:
    print("writing prediction : {}".format(write_path))
    w.write("id,prediction\n")
    for id, p in enumerate(meta_test_pred):
        w.write('{},{}\n'.format(id,p))
# Out:
# writing prediction : output/lgbm/meta_xg_lgbm.csv
