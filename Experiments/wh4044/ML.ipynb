# %%
import pandas as pd
import numpy as np
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
import os
import random

# %% [markdown]
# # 데이터 준비

# %%
train_df = pd.read_csv("/opt/ml/input/data/train_data.csv")
test_df = pd.read_csv("/opt/ml/input/data/test_data.csv")

# %%
def feature_engineering(df):
    
    #유저별 시퀀스를 고려하기 위해 아래와 같이 정렬
    df.sort_values(by=['userID','Timestamp'], inplace=True)
    
    #유저들의 문제 풀이수, 정답 수, 정답률을 시간순으로 누적해서 계산
    df['user_correct_answer'] = df.groupby('userID')['answerCode'].transform(lambda x: x.cumsum().shift(1))
    df['user_total_answer'] = df.groupby('userID')['answerCode'].cumcount()
    df['user_acc'] = df['user_correct_answer']/df['user_total_answer']

    # testId와 KnowledgeTag의 전체 정답률은 한번에 계산
    # 아래 데이터는 제출용 데이터셋에 대해서도 재사용
    correct_t = df.groupby(['testId'])['answerCode'].agg(['mean', 'sum'])
    correct_t.columns = ["test_mean", 'test_sum']
    correct_k = df.groupby(['KnowledgeTag'])['answerCode'].agg(['mean', 'sum'])
    correct_k.columns = ["tag_mean", 'tag_sum']

    df = pd.merge(df, correct_t, on=['testId'], how="left")
    df = pd.merge(df, correct_k, on=['KnowledgeTag'], how="left")
    
    return df

# %%
# train과 test 데이터셋은 사용자 별로 묶어서 분리를 해주어야함
random.seed(42)
def custom_train_test_split(df, ratio=0.7, split=True):
    
    users = list(zip(df['userID'].value_counts().index, df['userID'].value_counts()))
    random.shuffle(users)
    
    max_train_data_len = ratio*len(df)
    sum_of_train_data = 0
    user_ids =[]

    for user_id, count in users:
        sum_of_train_data += count
        if max_train_data_len < sum_of_train_data:
            break
        user_ids.append(user_id)


    train = df[df['userID'].isin(user_ids)]
    test = df[df['userID'].isin(user_ids) == False]

    #test데이터셋은 각 유저의 마지막 interaction만 추출
    test = test[test['userID'] != test['userID'].shift(-1)]
    return train, test

# %%
test_df_pre = feature_engineering(test_df)
df_infer = test_df_pre.loc[test_df['answerCode'] == -1].reset_index(drop=True)
df_infer
# Out:
#      userID assessmentItemID      testId  answerCode            Timestamp  \
# 0         3       A050133008  A050000133          -1  2020-10-26 13:13:57
# 1         4       A070146008  A070000146          -1  2020-12-27 02:47:54
# 2        13       A070111008  A070000111          -1  2020-12-27 04:35:09
# 3        17       A090064006  A090000064          -1  2020-10-30 05:48:37
# 4        26       A060135007  A060000135          -1  2020-10-23 11:44:18
# ..      ...              ...         ...         ...                  ...
# 739    7395       A040122005  A040000122          -1  2020-09-08 02:05:20
# 740    7404       A030111005  A030000111          -1  2020-10-13 09:49:18
# 741    7416       A050193004  A050000193          -1  2020-10-04 02:44:41
# 742    7417       A050193004  A050000193          -1  2020-09-06 13:09:15
# 743    7439       A040130005  A040000130          -1  2020-10-14 23:10:03
#
#      KnowledgeTag  user_correct_answer  user_total_answer  user_acc  \
# 0            5289                717.0               1035  0.692754
# 1            9080                465.0                670  0.694030
# 2            9660                915.0               1316  0.695289
# 3            2611               1031.0               1259  0.818904
# 4            1422                293.0                386  0.759067
# ..            ...                  ...                ...       ...
# 739         10615                  7.0                 23  0.304348
# 740          7636                  7.0                 14  0.500000
# 741         10402                  7.0                 14  0.500000
# 742         10402                  2.0                 14  0.142857
# 743          8832                 11.0                 15  0.733333
#
#      test_mean  test_sum  tag_mean  tag_sum
# 0     0.661765        90  0.542662      159
# 1     0.740385        77  0.565693      155
# 2     0.417857       117  0.446753      172
# 3     0.625000        30  0.514286       36
# 4     0.678571       133  0.602767      305
# ..         ...       ...       ...      ...
# 739   0.753846       147  0.654902      167
# 740   0.866667       156  0.834661      419
# 741   0.750000        75  0.792517      233
# 742   0.750000        75  0.792517      233
# 743   0.604762       127  0.584848      193
#
# [744 rows x 13 columns]

# %% [markdown]
# # 캣부스트

# %%
from catboost import CatBoostClassifier, Pool
train_df = feature_engineering(train_df)
train, test = custom_train_test_split(train_df)

# %%
# categorical_cols =  ['userID', 'assessmentItemID', 'testId', 'KnowledgeTag']
categorical_cols =  ['assessmentItemID', 'testId', 'KnowledgeTag']
train = train[['assessmentItemID', 'testId', 'KnowledgeTag','answerCode', 'user_correct_answer', 'user_total_answer', 
         'user_acc', 'test_mean', 'test_sum', 'tag_mean','tag_sum']]
train[categorical_cols] = train[categorical_cols].fillna("")
# train.drop(columns=['Timestamp'], inplace=True)
train
# Out:
#         assessmentItemID      testId  KnowledgeTag  answerCode  \
# 745           A040013001  A040000013          2048           1
# 746           A040013002  A040000013          2048           1
# 747           A040013003  A040000013          2047           1
# 748           A040013004  A040000013          2047           1
# 749           A040013005  A040000013          2047           0
# ...                  ...         ...           ...         ...
# 2266572       A030197001  A030000197          1984           1
# 2266573       A030197002  A030000197          1984           0
# 2266574       A030197003  A030000197          1984           0
# 2266575       A030197004  A030000197          1984           0
# 2266576       A030197005  A030000197          1984           0
#
#          user_correct_answer  user_total_answer  user_acc  test_mean  \
# 745                      NaN                  0       NaN   0.595472
# 746                      1.0                  1  1.000000   0.595472
# 747                      2.0                  2  1.000000   0.595472
# 748                      3.0                  3  1.000000   0.595472
# 749                      4.0                  4  1.000000   0.595472
# ...                      ...                ...       ...        ...
# 2266572                  5.0                 10  0.500000   0.738462
# 2266573                  6.0                 11  0.545455   0.738462
# 2266574                  6.0                 12  0.500000   0.738462
# 2266575                  6.0                 13  0.461538   0.738462
# 2266576                  6.0                 14  0.428571   0.738462
#
#          test_sum  tag_mean  tag_sum
# 745           789  0.616900      971
# 746           789  0.616900      971
# 747           789  0.570962     1050
# 748           789  0.570962     1050
# 749           789  0.570962     1050
# ...           ...       ...      ...
# 2266572      1008  0.749632     2039
# 2266573      1008  0.749632     2039
# 2266574      1008  0.749632     2039
# 2266575      1008  0.749632     2039
# 2266576      1008  0.749632     2039
#
# [1586157 rows x 11 columns]

# %%
TARGET_COL = 'answerCode'
X_train = train.drop([TARGET_COL],axis=1)
y_train = train[TARGET_COL]

train_pool = Pool(data=X_train,label = y_train,cat_features=categorical_cols)

# %%
# test_pool
# categorical_cols =  ['userID', 'assessmentItemID', 'testId', 'KnowledgeTag']
categorical_cols =  ['assessmentItemID', 'testId', 'KnowledgeTag']
test = test[['assessmentItemID', 'testId', 'KnowledgeTag','answerCode', 'user_correct_answer', 'user_total_answer', 
         'user_acc', 'test_mean', 'test_sum', 'tag_mean','tag_sum']]
test[categorical_cols] = test[categorical_cols].fillna("")
# test.drop(columns=['Timestamp'], inplace=True)

TARGET_COL = 'answerCode'
X_test = test.drop([TARGET_COL],axis=1)
y_test = test[TARGET_COL]

test_pool = Pool(data=X_test,label = y_test,cat_features=categorical_cols)

# %%
# infer_pool
# df_infer = feature_engineering(df_infer)
# categorical_cols =  ['userID', 'assessmentItemID', 'testId', 'KnowledgeTag']
categorical_cols =  ['assessmentItemID', 'testId', 'KnowledgeTag']
df_infer = df_infer[['assessmentItemID', 'testId', 'KnowledgeTag','answerCode', 'user_correct_answer', 'user_total_answer', 
         'user_acc', 'test_mean', 'test_sum', 'tag_mean','tag_sum']]
df_infer[categorical_cols] = df_infer[categorical_cols].fillna("")
# df_infer.drop(columns=['Timestamp'], inplace=True)

TARGET_COL = 'answerCode'
X_infer = df_infer.drop([TARGET_COL],axis=1)
y_infer = df_infer[TARGET_COL]

infer_pool = Pool(data=X_infer,label = y_infer,cat_features=categorical_cols)
# Out:
# /tmp/ipykernel_18682/1667055603.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_infer[categorical_cols] = df_infer[categorical_cols].fillna("")

# %%
params = {'iterations':5000,
          'random_seed':63,
          'learning_rate':0.01,
          # 'max_depth' : 10,
          'eval_metric' : 'AUC',
          # 'objective' : 'CrossEntropy',
        #   'loss_function':'CrossEntropy',
          # 'custom_metric':['Logloss','AUC'],##, '
          'early_stopping_rounds':100,
          'use_best_model': True,
          'task_type':"GPU",
        #   'bagging_temperature':1,
          'verbose':100}

# %%
model_basic = CatBoostClassifier(**params)#,learning_rate=0.1, task_type="GPU",)
# model_basic = CatBoostClassifier(verbose=50)#,learning_rate=0.1, task_type="GPU",)
model_basic.fit(train_pool, eval_set=test_pool, use_best_model=True)
print(model_basic.get_best_score())
# Out:
# 0:	test: 0.7096283	best: 0.7096283 (0)	total: 45ms	remaining: 3m 45s
# 100:	test: 0.7335236	best: 0.7335236 (100)	total: 4.46s	remaining: 3m 36s
# 200:	test: 0.7362826	best: 0.7362826 (200)	total: 9.75s	remaining: 3m 52s
# 300:	test: 0.7383969	best: 0.7384347 (299)	total: 15.1s	remaining: 3m 55s
# 400:	test: 0.7396531	best: 0.7396531 (400)	total: 20.4s	remaining: 3m 53s
# 500:	test: 0.7404800	best: 0.7405019 (490)	total: 25.8s	remaining: 3m 51s
# 600:	test: 0.7409740	best: 0.7409938 (594)	total: 31.1s	remaining: 3m 47s
# 700:	test: 0.7413178	best: 0.7413178 (700)	total: 36.3s	remaining: 3m 42s
# 800:	test: 0.7416145	best: 0.7416508 (792)	total: 41.6s	remaining: 3m 37s
# 900:	test: 0.7417924	best: 0.7418152 (882)	total: 46.8s	remaining: 3m 33s
# bestTest = 0.7418152392
# bestIteration = 882
# Shrink model to first 883 iterations.
# {'learn': {'Logloss': 0.5260044008884367}, 'validation': {'Logloss': 0.6022343428858371, 'AUC': 0.7418152391910553}}

# %%
print("train ACC :", model_basic.score(train_pool))
print("test ACC :", model_basic.score(test_pool))

pred = model_basic.predict_proba(test_pool)[:,1]
print("test AUC :", roc_auc_score(y_test, pred))
# Out:
# train ACC : 0.7440782974194862
# test ACC : 0.6781265570503239
# test AUC : 0.7418162393162394

# %%
print("test set 평균, 최대값, 최소값")
print(pred.mean())
print(pred.max())
print(pred.min())
# Out:
# test set 평균, 최대값, 최소값
# 0.5296340005876892
# 0.9630352145295576
# 0.06839380770802914

# %%
# inference
infer_cbc = model_basic.predict_proba(infer_pool)[:,1]
infer_cbc[:10]
# Out:
# array([0.59013311, 0.69597954, 0.46701134, 0.65193911, 0.37170677,
#        0.8175224 , 0.56512769, 0.26366763, 0.25907911, 0.8223259 ])

# %%
print("infer set 평균, 최대값, 최소값")
print(infer_cbc.mean())
print(infer_cbc.max())
print(infer_cbc.min())
# Out:
# infer set 평균, 최대값, 최소값
# 0.5205111221616208
# 0.9589302419928564
# 0.09271138075620447

# %%
output = pd.read_csv("xgbc.csv")

output['prediction'] = infer_cbc
output.to_csv("cbc2.csv", index=False)

# %%
bm = pd.read_csv("lgbm_sunny.csv")
cn = pd.read_csv("lgcn_sunny.csv")

total = (bm['prediction'] * 0.9 + cn['prediction'] * 0.9 + infer_cbc * 1.2) / 3
total
# Out:
# 0      0.592945
# 1      0.754369
# 2      0.451799
# 3      0.749818
# 4      0.431325
#          ...
# 739    0.143949
# 740    0.757912
# 741    0.777485
# 742    0.480022
# 743    0.539645
# Name: prediction, Length: 744, dtype: float64

# %%
print("infer set 평균, 최대값, 최소값")
print(total.mean())
print(total.max())
print(total.min())
# Out:
# infer set 평균, 최대값, 최소값
# 0.5151900090383756
# 0.9535746351924256
# 0.061973999622638665

# %%
output['prediction'] = total
output.to_csv("ensemble3.csv", index=False)

# %% [markdown]
# # 랜덤 포레스트

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_jobs=-1, random_state=42, min_impurity_decrease = 0.0000002)

# %%
df = pd.concat([train_df, test_df]).reset_index(drop=True)
# df = feature_engineering(df)

user2idx = {j:i for i, j in enumerate(sorted(df['userID'].unique()))}
assess2idx = {j:i for i, j in enumerate(sorted(df['assessmentItemID'].unique()))}
test2idx = {j:i for i, j in enumerate(sorted(df['testId'].unique()))}
know2idx = {j:i for i, j in enumerate(sorted(df['KnowledgeTag'].unique()))}

# %% [markdown]
# ---

# %%
# df_temp = df.drop_duplicates(subset=['userID', 'assessmentItemID']).reset_index(drop=True)
df_temp = feature_engineering(df)

# infer
df_infer_xg = df_temp.loc[df_temp['answerCode'] == -1].reset_index(drop=True)
df_infer_xg = change2idx(df_infer_xg)
df_infer_xg = df_infer_xg[['assessmentItemID', 'testId', 'KnowledgeTag', 'user_correct_answer', 'user_total_answer', 
         'user_acc', 'test_mean', 'test_sum', 'tag_mean','tag_sum']]

# %%
df_infer_xg
# Out:
#      assessmentItemID  testId  KnowledgeTag  user_correct_answer  \
# 0                4965     914           469                717.0
# 1                7748    1306           781                465.0
# 2                7484    1271           820                915.0
# 3                9381    1526           309               1031.0
# 4                6231    1109           183                293.0
# ..                ...     ...           ...                  ...
# 739              3692     705           883                  7.0
# 740              2590     496           589                  7.0
# 741              5353     974           865                  7.0
# 742              5353     974           865                  2.0
# 743              3732     713           719                 11.0
#
#      user_total_answer  user_acc  test_mean  test_sum  tag_mean  tag_sum
# 0                 1035  0.692754   0.654500      1309  0.559077     1817
# 1                  670  0.694030   0.645000       774  0.541569     1381
# 2                 1316  0.695289   0.456000       912  0.492333     1477
# 3                 1259  0.818904   0.443333       266  0.417647      355
# 4                  386  0.759067   0.639429      1119  0.609263     2894
# ..                 ...       ...        ...       ...       ...      ...
# 739                 23  0.304348   0.790000      1185  0.700952     1472
# 740                 14  0.500000   0.866000      1299  0.824167     3956
# 741                 14  0.500000   0.746000       746  0.820896     2750
# 742                 14  0.142857   0.746000       746  0.820896     2750
# 743                 15  0.733333   0.639333       959  0.637778     1722
#
# [744 rows x 10 columns]

# %%
df_temp = df_temp.loc[df_temp['answerCode'] != -1].reset_index(drop=True)
df_temp
# Out:
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 0             0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1             0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2             0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3             0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4             0       A060001005  A060000001           1  2020-03-24 00:17:36
# ...         ...              ...         ...         ...                  ...
# 2525951    7441       A030071005  A030000071           0  2020-06-05 06:50:21
# 2525952    7441       A040165001  A040000165           1  2020-08-21 01:06:39
# 2525953    7441       A040165002  A040000165           1  2020-08-21 01:06:50
# 2525954    7441       A040165003  A040000165           1  2020-08-21 01:07:36
# 2525955    7441       A040165004  A040000165           1  2020-08-21 01:08:49
#
#          KnowledgeTag  user_correct_answer  user_total_answer  user_acc  \
# 0                7224                  NaN                  0       NaN
# 1                7225                  1.0                  1  1.000000
# 2                7225                  2.0                  2  1.000000
# 3                7225                  3.0                  3  1.000000
# 4                7225                  4.0                  4  1.000000
# ...               ...                  ...                ...       ...
# 2525951           438                  1.0                  4  0.250000
# 2525952          8836                  1.0                  5  0.200000
# 2525953          8836                  2.0                  6  0.333333
# 2525954          8836                  3.0                  7  0.428571
# 2525955          8836                  4.0                  8  0.500000
#
#          test_mean  test_sum  tag_mean  tag_sum
# 0         0.952667      1429  0.957333      718
# 1         0.952667      1429  0.917067     3439
# 2         0.952667      1429  0.917067     3439
# 3         0.952667      1429  0.917067     3439
# 4         0.952667      1429  0.917067     3439
# ...            ...       ...       ...      ...
# 2525951   0.666000       999  0.694889     3127
# 2525952   0.652500       783  0.698551     2410
# 2525953   0.652500       783  0.698551     2410
# 2525954   0.652500       783  0.698551     2410
# 2525955   0.652500       783  0.698551     2410
#
# [2525956 rows x 13 columns]

# %%
train_xg, test_xg = custom_train_test_split(df_temp)
print(train_xg.shape, test_xg.shape)
# Out:
# (1768018, 13) (2235, 13)

# %%
train_xg = change2idx(train_xg.reset_index(drop=True))
test_xg = change2idx(test_xg.reset_index(drop=True))

# %%
train_xg.dropna(inplace=True)
test_xg.dropna(inplace=True)

# %%
train_xg_X = train_xg[['assessmentItemID', 'testId', 'KnowledgeTag', 'user_correct_answer', 'user_total_answer', 
         'user_acc', 'test_mean', 'test_sum', 'tag_mean','tag_sum']]
train_xg_y = train_xg['answerCode']

test_xg_X = test_xg[['assessmentItemID', 'testId', 'KnowledgeTag', 'user_correct_answer', 'user_total_answer', 
         'user_acc', 'test_mean', 'test_sum', 'tag_mean','tag_sum']]
test_xg_y = test_xg['answerCode']

# %%
# # infer
# df_infer_xg = df_temp.loc[df_temp['answerCode'] == -1].reset_index(drop=True)
# df_infer_xg = change2idx(df_infer_xg)
# df_infer_xg = df_infer_xg[['assessmentItemID', 'testId', 'KnowledgeTag', 'user_correct_answer', 'user_total_answer', 
#          'user_acc', 'test_mean', 'test_sum', 'tag_mean','tag_sum']]

# %%
train_xg_X
# Out:
#          assessmentItemID  testId  KnowledgeTag  user_correct_answer  \
# 1                    5355     975           557                  1.0
# 2                    5356     975           557                  2.0
# 3                    5357     975           557                  3.0
# 4                    5358     975           557                  4.0
# 5                    5359     975           557                  5.0
# ...                   ...     ...           ...                  ...
# 1768013              3047     582           236                  5.0
# 1768014              3048     582           236                  6.0
# 1768015              3049     582           236                  6.0
# 1768016              3050     582           236                  6.0
# 1768017              3051     582           236                  6.0
#
#          user_total_answer  user_acc  test_mean  test_sum  tag_mean  tag_sum
# 1                        1  1.000000   0.952667      1429  0.917067     3439
# 2                        2  1.000000   0.952667      1429  0.917067     3439
# 3                        3  1.000000   0.952667      1429  0.917067     3439
# 4                        4  1.000000   0.952667      1429  0.917067     3439
# 5                        5  1.000000   0.952667      1429  0.917067     3439
# ...                    ...       ...        ...       ...       ...      ...
# 1768013                 10  0.500000   0.728000      1092  0.741356     2187
# 1768014                 11  0.545455   0.728000      1092  0.741356     2187
# 1768015                 12  0.500000   0.728000      1092  0.741356     2187
# 1768016                 13  0.461538   0.728000      1092  0.741356     2187
# 1768017                 14  0.428571   0.728000      1092  0.741356     2187
#
# [1762811 rows x 10 columns]

# %%
test_xg_X
# Out:
#       assessmentItemID  testId  KnowledgeTag  user_correct_answer  \
# 0                 7747    1306           781                464.0
# 1                 7087    1220           167                344.0
# 2                 7872    1322           792                407.0
# 3                 6230    1109           183                293.0
# 4                 7756    1307           783                317.0
# ...                ...     ...           ...                  ...
# 2230              3824     732           283                 11.0
# 2231              6376    1130           192                  7.0
# 2232              2093     404            20                  7.0
# 2233              3731     713           697                 10.0
# 2234              3912     748           720                  4.0
#
#       user_total_answer  user_acc  test_mean  test_sum  tag_mean  tag_sum
# 0                   669  0.693572   0.645000       774  0.541569     1381
# 1                   535  0.642991   0.517333       776  0.462000     3696
# 2                   605  0.672727   0.550000       440  0.360571      631
# 3                   385  0.761039   0.639429      1119  0.609263     2894
# 4                   689  0.460087   0.501500      1003  0.544706      926
# ...                 ...       ...        ...       ...       ...      ...
# 2230                 14  0.785714   0.780000      1170  0.718958     3451
# 2231                 14  0.500000   0.689600       862  0.714286     1250
# 2232                 14  0.500000   0.687333      1031  0.733333     1100
# 2233                 14  0.714286   0.639333       959  0.762500      915
# 2234                  8  0.500000   0.652500       783  0.698551     2410
#
# [2235 rows x 10 columns]

# %% [markdown]
# ---

# %%
def change2idx(df):
    # df['userID'] = df['userID'].apply(lambda x : user2idx[x])
    df['assessmentItemID'] = df['assessmentItemID'].apply(lambda x : assess2idx[x])
    df['testId'] = df['testId'].apply(lambda x : test2idx[x])
    df['KnowledgeTag'] = df['KnowledgeTag'].apply(lambda x : know2idx[x])
    return df

# %%
train_rf = train.dropna()
train_rf = change2idx(train_rf)
X_train_rf = train_rf.drop([TARGET_COL], axis=1).values
y_train_rf = train_rf[TARGET_COL].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /opt/ml/input/ML.ipynb Cell 39' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B49.50.172.201/opt/ml/input/ML.ipynb#ch0000038vscode-remote?line=0'>1</a> train_rf = train.dropna()
#       <a href='vscode-notebook-cell://ssh-remote%2B49.50.172.201/opt/ml/input/ML.ipynb#ch0000038vscode-remote?line=1'>2</a> train_rf = change2idx(train_rf)
#       <a href='vscode-notebook-cell://ssh-remote%2B49.50.172.201/opt/ml/input/ML.ipynb#ch0000038vscode-remote?line=2'>3</a> X_train_rf = train_rf.drop([TARGET_COL], axis=1).values
#
# NameError: name 'train' is not defined

# %%
rf.fit(X_train_rf, y_train_rf)
# Out:
# RandomForestClassifier(min_impurity_decrease=2e-07, n_jobs=-1, random_state=42)

# %%
test_rf = test.dropna()
test_rf = change2idx(test_rf)
X_test_rf = test_rf.drop([TARGET_COL], axis=1).values
y_test_rf = test_rf[TARGET_COL].values

# %%
infer_rf = change2idx(df_infer)
X_infer_rf = infer_rf.drop([TARGET_COL], axis=1).values
# Out:
# /tmp/ipykernel_18682/3078986543.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['assessmentItemID'] = df['assessmentItemID'].apply(lambda x : assess2idx[x])
# /tmp/ipykernel_18682/3078986543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['testId'] = df['testId'].apply(lambda x : test2idx[x])
# /tmp/ipykernel_18682/3078986543.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['KnowledgeTag'] = df['KnowledgeTag'].apply(lambda x : know2idx[x])

# %%
print("train ACC :", rf.score(X_train_rf, y_train_rf))
print("test ACC :", rf.score(X_test_rf, y_test_rf))

pred = rf.predict_proba(X_test_rf)[:,1]
print("test AUC :", roc_auc_score(y_test_rf, pred))
# Out:
# train ACC : 0.9605840403777255
# test ACC : 0.615346287992028
# test AUC : 0.669869310276287

# %%
infer_rfc = rf.predict_proba(X_infer_rf)[:, 1]
infer_rfc[:10]
# Out:
# array([0.52282057, 0.58698249, 0.45425311, 0.60221068, 0.80316091,
#        0.63400228, 0.61209546, 0.55617954, 0.30067077, 0.73985769])

# %%
print("infer set 평균, 최대값, 최소값")
print(infer_rfc.mean())
print(infer_rfc.max())
print(infer_rfc.min())
# Out:
# infer set 평균, 최대값, 최소값
# 0.57053491079615
# 0.9246656634739304
# 0.12589701760265806

# %% [markdown]
# # XG부스트

# %% [markdown]
# ---

# %%
import xgboost as xgb
dtrain = xgb.DMatrix(train_xg_X, train_xg_y)
dval = xgb.DMatrix(test_xg_X, test_xg_y)
dtest = xgb.DMatrix(df_infer_xg)

# %%
# 모델 생성
# num_boost_round 만큼 반복하는데 early_stopping_rounds 만큼 성능 향상이 없으면 중단
# early_stopping_rounds를 사용하려면 eval 데이터 셋을 명기해야함
# param = {파라미터 설정}
params1 = {
    'seed' : 42,
    'eta': 0.1,
    'objective': 'binary:logistic',
    'min_child_weight': 1,
    'eval_metric': 'auc',
    # 'n_estimators': 2000,
    # 'early_stopping_rounds': 100,
    'max_depth': 5,
    'lambda' : 0.5 
    # 'max_leaves':5, 
    }

xgb_model = xgb.train(
                    params = params1, 
                    dtrain = dtrain, 
                    num_boost_round = 400, 
                    early_stopping_rounds = 30, 
                    evals=[(dtrain,'train'),(dval,'eval')]
                    )

# %%
# 예측하기, 확률값으로 반환됨
train_pred = xgb_model.predict(dtrain)
test_pred = xgb_model.predict(dval)

# %%
print(roc_auc_score(train_xg_y, train_pred))
print(roc_auc_score(test_xg_y, test_pred))
# Out:
# 0.7501453341890393
# 0.6986728795942324

# %%
xgb_model.predict(dtest)
# Out:
# array([0.6714251 , 0.69186723, 0.58297205, 0.8965642 , 0.6940091 ,
#        0.8096116 , 0.71061635, 0.6534531 , 0.23402894, 0.8730594 ,
#        0.7091386 , 0.67900926, 0.9449733 , 0.5633424 , 0.8788543 ,
#        0.867618  , 0.26812026, 0.8672425 , 0.7820452 , 0.45185453,
#        0.8322462 , 0.5425873 , 0.48899218, 0.6851879 , 0.55609727,
#        0.7269843 , 0.91548985, 0.88791263, 0.60836583, 0.76859176,
#        0.5750762 , 0.78953654, 0.78450143, 0.45800975, 0.78571784,
#        0.70640355, 0.69666076, 0.5800986 , 0.62601346, 0.5750419 ,
#        0.6747439 , 0.47476095, 0.34010002, 0.38200086, 0.46427017,
#        0.73143053, 0.7476703 , 0.2431307 , 0.9232747 , 0.7372267 ,
#        0.5925137 , 0.5246484 , 0.64087296, 0.45996702, 0.7155116 ,
#        0.6703693 , 0.60551846, 0.9385981 , 0.5496929 , 0.61548656,
#        0.8417219 , 0.93898624, 0.43242228, 0.43038586, 0.18434143,
#        0.5853126 , 0.7739745 , 0.34861752, 0.32737848, 0.50347584,
#        0.59834456, 0.8518308 , 0.57753986, 0.49151623, 0.777436  ,
#        0.5754961 , 0.26798826, 0.6989602 , 0.6334091 , 0.79977334,
#        0.439286  , 0.7861949 , 0.5891029 , 0.7546173 , 0.81856036,
#        0.4330854 , 0.65939957, 0.332137  , 0.75451034, 0.3478452 ,
#        0.31080747, 0.2758576 , 0.45709434, 0.91611135, 0.8638541 ,
#        0.74036634, 0.25057584, 0.56088847, 0.81450284, 0.73126805,
#        0.740224  , 0.7205931 , 0.9158463 , 0.35404003, 0.825011  ,
#        0.88063496, 0.6464885 , 0.8056737 , 0.5869714 , 0.37665623,
#        0.75793636, 0.8247176 , 0.38816604, 0.32432145, 0.55164516,
#        0.81004304, 0.7846242 , 0.2627099 , 0.544639  , 0.27095172,
#        0.24433418, 0.17608954, 0.426753  , 0.6754241 , 0.7588036 ,
#        0.69588494, 0.8094148 , 0.6354842 , 0.8874226 , 0.62548566,
#        0.70527077, 0.58569473, 0.61325264, 0.46405905, 0.26250434,
#        0.81738716, 0.44261086, 0.7511212 , 0.6075484 , 0.4390897 ,
#        0.7024387 , 0.7162009 , 0.55537444, 0.5622391 , 0.553403  ,
#        0.4121988 , 0.7055525 , 0.56790876, 0.8244138 , 0.6584512 ,
#        0.86625314, 0.22865897, 0.3070606 , 0.7447368 , 0.5721487 ,
#        0.6741099 , 0.58840513, 0.63644296, 0.7002745 , 0.7018385 ,
#        0.6805857 , 0.703505  , 0.57931244, 0.74601215, 0.5712708 ,
#        0.75982946, 0.6529583 , 0.42167997, 0.64226437], dtype=float32)

# %% [markdown]
# ---

# %%
params = {
    'seed' : 42,
    'learning_rate': 0.05,
    'objective': 'binary:logistic',
    'min_child_weight': 1,
    'eval_metric': 'auc',
    'n_estimators': 2000,
    'early_stopping_rounds': 100,
    'max_depth': 12, 
    'max_leaves':5, 
    # 'min_child_weigh'1
    }

# %%
import xgboost as xgb
from xgboost import XGBClassifier
xg = XGBClassifier(**params)
# xg = XGBClassifier(eval_metric='auc')

# %%
xg.fit(train_xg_X, train_xg_y, eval_set=[(test_xg_X, test_xg_y)])
# Out:
# [0]	validation_0-auc:0.68406
# [1]	validation_0-auc:0.68820
# [2]	validation_0-auc:0.68873
# [3]	validation_0-auc:0.68710
# [4]	validation_0-auc:0.68641
# [5]	validation_0-auc:0.68675
# [6]	validation_0-auc:0.68744
# [7]	validation_0-auc:0.68750
# [8]	validation_0-auc:0.68817
# [9]	validation_0-auc:0.68815
# [10]	validation_0-auc:0.68886
# [11]	validation_0-auc:0.68946
# [12]	validation_0-auc:0.68934
# [13]	validation_0-auc:0.68960
# [14]	validation_0-auc:0.68945
# [15]	validation_0-auc:0.68915
# [16]	validation_0-auc:0.68931
# [17]	validation_0-auc:0.68946
# [18]	validation_0-auc:0.68948
# [19]	validation_0-auc:0.68964
# [20]	validation_0-auc:0.68963
# [21]	validation_0-auc:0.68956
# [22]	validation_0-auc:0.68930
# [23]	validation_0-auc:0.68960
# [24]	validation_0-auc:0.68949
# [25]	validation_0-auc:0.68979
# [26]	validation_0-auc:0.68990
# [27]	validation_0-auc:0.68981
# [28]	validation_0-auc:0.69013
# [29]	validation_0-auc:0.69056
# [30]	validation_0-auc:0.69063
# [31]	validation_0-auc:0.69104
# [32]	validation_0-auc:0.69118
# [33]	validation_0-auc:0.69115
# [34]	validation_0-auc:0.69096
# [35]	validation_0-auc:0.69092
# [36]	validation_0-auc:0.69088
# [37]	validation_0-auc:0.69081
# [38]	validation_0-auc:0.69059
# [39]	validation_0-auc:0.69043
# [40]	validation_0-auc:0.69069
# [41]	validation_0-auc:0.69058
# [42]	validation_0-auc:0.69089
# [43]	validation_0-auc:0.69053
# [44]	validation_0-auc:0.69026
# [45]	validation_0-auc:0.69035
# [46]	validation_0-auc:0.69043
# [47]	validation_0-auc:0.69071
# [48]	validation_0-auc:0.69092
# [49]	validation_0-auc:0.69142
# [50]	validation_0-auc:0.69156
# [51]	validation_0-auc:0.69148
# [52]	validation_0-auc:0.69146
# [53]	validation_0-auc:0.69157
# [54]	validation_0-auc:0.69202
# [55]	validation_0-auc:0.69192
# [56]	validation_0-auc:0.69222
# [57]	validation_0-auc:0.69236
# [58]	validation_0-auc:0.69251
# [59]	validation_0-auc:0.69243
# [60]	validation_0-auc:0.69281
# [61]	validation_0-auc:0.69284
# [62]	validation_0-auc:0.69283
# [63]	validation_0-auc:0.69292
# [64]	validation_0-auc:0.69300
# [65]	validation_0-auc:0.69324
# [66]	validation_0-auc:0.69338
# [67]	validation_0-auc:0.69346
# [68]	validation_0-auc:0.69355
# [69]	validation_0-auc:0.69372
# [70]	validation_0-auc:0.69391
# [71]	validation_0-auc:0.69400
# [72]	validation_0-auc:0.69392
# [73]	validation_0-auc:0.69421
# [74]	validation_0-auc:0.69433
# [75]	validation_0-auc:0.69435
# [76]	validation_0-auc:0.69440
# [77]	validation_0-auc:0.69441
# [78]	validation_0-auc:0.69448
# [79]	validation_0-auc:0.69441
# [80]	validation_0-auc:0.69454
# [81]	validation_0-auc:0.69456
# [82]	validation_0-auc:0.69425
# [83]	validation_0-auc:0.69450
# [84]	validation_0-auc:0.69480
# [85]	validation_0-auc:0.69480
# [86]	validation_0-auc:0.69492
# [87]	validation_0-auc:0.69486
# [88]	validation_0-auc:0.69506
# [89]	validation_0-auc:0.69555
# [90]	validation_0-auc:0.69555
# [91]	validation_0-auc:0.69561
# [92]	validation_0-auc:0.69603
# [93]	validation_0-auc:0.69625
# [94]	validation_0-auc:0.69619
# [95]	validation_0-auc:0.69617
# [96]	validation_0-auc:0.69621
# [97]	validation_0-auc:0.69614
# [98]	validation_0-auc:0.69617
# [99]	validation_0-auc:0.69607
# [100]	validation_0-auc:0.69621
# [101]	validation_0-auc:0.69622
# [102]	validation_0-auc:0.69623
# [103]	validation_0-auc:0.69652
# [104]	validation_0-auc:0.69657
# [105]	validation_0-auc:0.69667
# [106]	validation_0-auc:0.69668
# [107]	validation_0-auc:0.69680
# [108]	validation_0-auc:0.69672
# [109]	validation_0-auc:0.69672
# [110]	validation_0-auc:0.69726
# [111]	validation_0-auc:0.69724
# [112]	validation_0-auc:0.69729
# [113]	validation_0-auc:0.69733
# [114]	validation_0-auc:0.69736
# [115]	validation_0-auc:0.69723
# [116]	validation_0-auc:0.69715
# [117]	validation_0-auc:0.69717
# [118]	validation_0-auc:0.69710
# [119]	validation_0-auc:0.69713
# [120]	validation_0-auc:0.69711
# [121]	validation_0-auc:0.69714
# [122]	validation_0-auc:0.69722
# [123]	validation_0-auc:0.69736
# [124]	validation_0-auc:0.69734
# [125]	validation_0-auc:0.69737
# [126]	validation_0-auc:0.69750
# [127]	validation_0-auc:0.69788
# [128]	validation_0-auc:0.69785
# [129]	validation_0-auc:0.69783
# [130]	validation_0-auc:0.69783
# [131]	validation_0-auc:0.69820
# [132]	validation_0-auc:0.69825
# [133]	validation_0-auc:0.69825
# [134]	validation_0-auc:0.69827
# [135]	validation_0-auc:0.69826
# [136]	validation_0-auc:0.69843
# [137]	validation_0-auc:0.69846
# [138]	validation_0-auc:0.69854
# [139]	validation_0-auc:0.69859
# [140]	validation_0-auc:0.69857
# [141]	validation_0-auc:0.69882
# [142]	validation_0-auc:0.69877
# [143]	validation_0-auc:0.69875
# [144]	validation_0-auc:0.69870
# [145]	validation_0-auc:0.69854
# [146]	validation_0-auc:0.69854
# [147]	validation_0-auc:0.69852
# [148]	validation_0-auc:0.69863
# [149]	validation_0-auc:0.69868
# [150]	validation_0-auc:0.69870
# [151]	validation_0-auc:0.69878
# [152]	validation_0-auc:0.69859
# [153]	validation_0-auc:0.69859
# [154]	validation_0-auc:0.69865
# [155]	validation_0-auc:0.69867
# [156]	validation_0-auc:0.69863
# [157]	validation_0-auc:0.69863
# [158]	validation_0-auc:0.69860
# [159]	validation_0-auc:0.69863
# [160]	validation_0-auc:0.69863
# [161]	validation_0-auc:0.69873
# [162]	validation_0-auc:0.69878
# [163]	validation_0-auc:0.69900
# [164]	validation_0-auc:0.69906
# [165]	validation_0-auc:0.69928
# [166]	validation_0-auc:0.69932
# [167]	validation_0-auc:0.69939
# [168]	validation_0-auc:0.69947
# [169]	validation_0-auc:0.69947
# [170]	validation_0-auc:0.69948
# [171]	validation_0-auc:0.69955
# [172]	validation_0-auc:0.69961
# [173]	validation_0-auc:0.69967
# [174]	validation_0-auc:0.69929
# [175]	validation_0-auc:0.69924
# [176]	validation_0-auc:0.69928
# [177]	validation_0-auc:0.69928
# [178]	validation_0-auc:0.69939
# [179]	validation_0-auc:0.69939
# [180]	validation_0-auc:0.69947
# [181]	validation_0-auc:0.69946
# [182]	validation_0-auc:0.69936
# [183]	validation_0-auc:0.69934
# [184]	validation_0-auc:0.69936
# [185]	validation_0-auc:0.69936
# [186]	validation_0-auc:0.69938
# [187]	validation_0-auc:0.69949
# [188]	validation_0-auc:0.69949
# [189]	validation_0-auc:0.69949
# [190]	validation_0-auc:0.69954
# [191]	validation_0-auc:0.69955
# [192]	validation_0-auc:0.69953
# [193]	validation_0-auc:0.69951
# [194]	validation_0-auc:0.69949
# [195]	validation_0-auc:0.69960
# [196]	validation_0-auc:0.69958
# [197]	validation_0-auc:0.69964
# [198]	validation_0-auc:0.69967
# [199]	validation_0-auc:0.69964
# [200]	validation_0-auc:0.69973
# [201]	validation_0-auc:0.69989
# [202]	validation_0-auc:0.69999
# [203]	validation_0-auc:0.69997
# [204]	validation_0-auc:0.69994
# [205]	validation_0-auc:0.70001
# [206]	validation_0-auc:0.69999
# [207]	validation_0-auc:0.70022
# [208]	validation_0-auc:0.70023
# [209]	validation_0-auc:0.70031
# [210]	validation_0-auc:0.70048
# [211]	validation_0-auc:0.70046
# [212]	validation_0-auc:0.70043
# [213]	validation_0-auc:0.70040
# [214]	validation_0-auc:0.70041
# [215]	validation_0-auc:0.70079
# [216]	validation_0-auc:0.70093
# [217]	validation_0-auc:0.70087
# [218]	validation_0-auc:0.70097
# [219]	validation_0-auc:0.70095
# [220]	validation_0-auc:0.70089
# [221]	validation_0-auc:0.70090
# [222]	validation_0-auc:0.70086
# [223]	validation_0-auc:0.70096
# [224]	validation_0-auc:0.70110
# [225]	validation_0-auc:0.70110
# [226]	validation_0-auc:0.70110
# [227]	validation_0-auc:0.70105
# [228]	validation_0-auc:0.70111
# [229]	validation_0-auc:0.70115
# [230]	validation_0-auc:0.70110
# [231]	validation_0-auc:0.70106
# [232]	validation_0-auc:0.70099
# [233]	validation_0-auc:0.70130
# [234]	validation_0-auc:0.70132
# [235]	validation_0-auc:0.70137
# [236]	validation_0-auc:0.70135
# [237]	validation_0-auc:0.70149
# [238]	validation_0-auc:0.70149
# [239]	validation_0-auc:0.70153
# [240]	validation_0-auc:0.70157
# [241]	validation_0-auc:0.70155
# [242]	validation_0-auc:0.70158
# [243]	validation_0-auc:0.70147
# [244]	validation_0-auc:0.70135
# [245]	validation_0-auc:0.70155
# [246]	validation_0-auc:0.70165
# [247]	validation_0-auc:0.70181
# [248]	validation_0-auc:0.70188
# [249]	validation_0-auc:0.70188
# [250]	validation_0-auc:0.70193
# [251]	validation_0-auc:0.70190
# [252]	validation_0-auc:0.70200
# [253]	validation_0-auc:0.70199
# [254]	validation_0-auc:0.70210
# [255]	validation_0-auc:0.70203
# [256]	validation_0-auc:0.70212
# [257]	validation_0-auc:0.70212
# [258]	validation_0-auc:0.70213
# [259]	validation_0-auc:0.70214
# [260]	validation_0-auc:0.70216
# [261]	validation_0-auc:0.70214
# [262]	validation_0-auc:0.70214
# [263]	validation_0-auc:0.70214
# [264]	validation_0-auc:0.70216
# [265]	validation_0-auc:0.70218
# [266]	validation_0-auc:0.70241
# [267]	validation_0-auc:0.70245
# [268]	validation_0-auc:0.70245
# [269]	validation_0-auc:0.70243
# [270]	validation_0-auc:0.70247
# [271]	validation_0-auc:0.70234
# [272]	validation_0-auc:0.70234
# [273]	validation_0-auc:0.70244
# [274]	validation_0-auc:0.70242
# [275]	validation_0-auc:0.70241
# [276]	validation_0-auc:0.70257
# [277]	validation_0-auc:0.70259
# [278]	validation_0-auc:0.70257
# [279]	validation_0-auc:0.70260
# [280]	validation_0-auc:0.70260
# [281]	validation_0-auc:0.70260
# [282]	validation_0-auc:0.70260
# [283]	validation_0-auc:0.70260
# [284]	validation_0-auc:0.70261
# [285]	validation_0-auc:0.70261
# [286]	validation_0-auc:0.70272
# [287]	validation_0-auc:0.70287
# [288]	validation_0-auc:0.70289
# [289]	validation_0-auc:0.70301
# [290]	validation_0-auc:0.70302
# [291]	validation_0-auc:0.70307
# [292]	validation_0-auc:0.70308
# [293]	validation_0-auc:0.70315
# [294]	validation_0-auc:0.70307
# [295]	validation_0-auc:0.70305
# [296]	validation_0-auc:0.70304
# [297]	validation_0-auc:0.70306
# [298]	validation_0-auc:0.70308
# [299]	validation_0-auc:0.70307
# [300]	validation_0-auc:0.70323
# [301]	validation_0-auc:0.70325
# [302]	validation_0-auc:0.70328
# [303]	validation_0-auc:0.70328
# [304]	validation_0-auc:0.70330
# [305]	validation_0-auc:0.70342
# [306]	validation_0-auc:0.70345
# [307]	validation_0-auc:0.70341
# [308]	validation_0-auc:0.70336
# [309]	validation_0-auc:0.70336
# [310]	validation_0-auc:0.70336
# [311]	validation_0-auc:0.70339
# [312]	validation_0-auc:0.70339
# [313]	validation_0-auc:0.70362
# [314]	validation_0-auc:0.70375
# [315]	validation_0-auc:0.70376
# [316]	validation_0-auc:0.70373
# [317]	validation_0-auc:0.70372
# [318]	validation_0-auc:0.70364
# [319]	validation_0-auc:0.70359
# [320]	validation_0-auc:0.70358
# [321]	validation_0-auc:0.70358
# [322]	validation_0-auc:0.70362
# [323]	validation_0-auc:0.70357
# [324]	validation_0-auc:0.70358
# [325]	validation_0-auc:0.70360
# [326]	validation_0-auc:0.70358
# [327]	validation_0-auc:0.70402
# [328]	validation_0-auc:0.70403
# [329]	validation_0-auc:0.70404
# [330]	validation_0-auc:0.70405
# [331]	validation_0-auc:0.70421
# [332]	validation_0-auc:0.70428
# [333]	validation_0-auc:0.70428
# [334]	validation_0-auc:0.70425
# [335]	validation_0-auc:0.70420
# [336]	validation_0-auc:0.70444
# [337]	validation_0-auc:0.70444
# [338]	validation_0-auc:0.70438
# [339]	validation_0-auc:0.70437
# [340]	validation_0-auc:0.70431
# [341]	validation_0-auc:0.70436
# [342]	validation_0-auc:0.70453
# [343]	validation_0-auc:0.70446
# [344]	validation_0-auc:0.70447
# [345]	validation_0-auc:0.70443
# [346]	validation_0-auc:0.70444
# [347]	validation_0-auc:0.70449
# [348]	validation_0-auc:0.70468
# [349]	validation_0-auc:0.70463
# [350]	validation_0-auc:0.70464
# [351]	validation_0-auc:0.70461
# [352]	validation_0-auc:0.70464
# [353]	validation_0-auc:0.70468
# [354]	validation_0-auc:0.70468
# [355]	validation_0-auc:0.70468
# [356]	validation_0-auc:0.70468
# [357]	validation_0-auc:0.70469
# [358]	validation_0-auc:0.70467
# [359]	validation_0-auc:0.70455
# [360]	validation_0-auc:0.70455
# [361]	validation_0-auc:0.70455
# [362]	validation_0-auc:0.70452
# [363]	validation_0-auc:0.70457
# [364]	validation_0-auc:0.70461
# [365]	validation_0-auc:0.70461
# [366]	validation_0-auc:0.70460
# [367]	validation_0-auc:0.70471
# [368]	validation_0-auc:0.70466
# [369]	validation_0-auc:0.70466
# [370]	validation_0-auc:0.70468
# [371]	validation_0-auc:0.70472
# [372]	validation_0-auc:0.70472
# [373]	validation_0-auc:0.70472
# [374]	validation_0-auc:0.70480
# [375]	validation_0-auc:0.70481
# [376]	validation_0-auc:0.70495
# [377]	validation_0-auc:0.70500
# [378]	validation_0-auc:0.70501
# [379]	validation_0-auc:0.70503
# [380]	validation_0-auc:0.70505
# [381]	validation_0-auc:0.70504
# [382]	validation_0-auc:0.70517
# [383]	validation_0-auc:0.70519
# [384]	validation_0-auc:0.70527
# [385]	validation_0-auc:0.70531
# [386]	validation_0-auc:0.70537
# [387]	validation_0-auc:0.70538
# [388]	validation_0-auc:0.70540
# [389]	validation_0-auc:0.70540
# [390]	validation_0-auc:0.70539
# [391]	validation_0-auc:0.70538
# [392]	validation_0-auc:0.70539
# [393]	validation_0-auc:0.70542
# [394]	validation_0-auc:0.70541
# [395]	validation_0-auc:0.70542
# [396]	validation_0-auc:0.70558
# [397]	validation_0-auc:0.70560
# [398]	validation_0-auc:0.70564
# [399]	validation_0-auc:0.70572
# [400]	validation_0-auc:0.70569
# [401]	validation_0-auc:0.70589
# [402]	validation_0-auc:0.70591
# [403]	validation_0-auc:0.70588
# [404]	validation_0-auc:0.70599
# [405]	validation_0-auc:0.70598
# [406]	validation_0-auc:0.70611
# [407]	validation_0-auc:0.70611
# [408]	validation_0-auc:0.70605
# [409]	validation_0-auc:0.70604
# [410]	validation_0-auc:0.70606
# [411]	validation_0-auc:0.70604
# [412]	validation_0-auc:0.70614
# [413]	validation_0-auc:0.70614
# [414]	validation_0-auc:0.70609
# [415]	validation_0-auc:0.70627
# [416]	validation_0-auc:0.70642
# [417]	validation_0-auc:0.70641
# [418]	validation_0-auc:0.70642
# [419]	validation_0-auc:0.70640
# [420]	validation_0-auc:0.70637
# [421]	validation_0-auc:0.70633
# [422]	validation_0-auc:0.70631
# [423]	validation_0-auc:0.70638
# [424]	validation_0-auc:0.70637
# [425]	validation_0-auc:0.70641
# [426]	validation_0-auc:0.70641
# [427]	validation_0-auc:0.70638
# [428]	validation_0-auc:0.70638
# [429]	validation_0-auc:0.70644
# [430]	validation_0-auc:0.70642
# [431]	validation_0-auc:0.70656
# [432]	validation_0-auc:0.70661
# [433]	validation_0-auc:0.70657
# [434]	validation_0-auc:0.70669
# [435]	validation_0-auc:0.70670
# [436]	validation_0-auc:0.70668
# [437]	validation_0-auc:0.70671
# [438]	validation_0-auc:0.70675
# [439]	validation_0-auc:0.70672
# [440]	validation_0-auc:0.70670
# [441]	validation_0-auc:0.70678
# [442]	validation_0-auc:0.70676
# [443]	validation_0-auc:0.70671
# [444]	validation_0-auc:0.70672
# [445]	validation_0-auc:0.70669
# [446]	validation_0-auc:0.70669
# [447]	validation_0-auc:0.70685
# [448]	validation_0-auc:0.70696
# [449]	validation_0-auc:0.70696
# [450]	validation_0-auc:0.70696
# [451]	validation_0-auc:0.70706
# [452]	validation_0-auc:0.70714
# [453]	validation_0-auc:0.70728
# [454]	validation_0-auc:0.70740
# [455]	validation_0-auc:0.70740
# [456]	validation_0-auc:0.70736
# [457]	validation_0-auc:0.70734
# [458]	validation_0-auc:0.70738
# [459]	validation_0-auc:0.70738
# [460]	validation_0-auc:0.70743
# [461]	validation_0-auc:0.70743
# [462]	validation_0-auc:0.70748
# [463]	validation_0-auc:0.70748
# [464]	validation_0-auc:0.70748
# [465]	validation_0-auc:0.70749
# [466]	validation_0-auc:0.70757
# [467]	validation_0-auc:0.70749
# [468]	validation_0-auc:0.70744
# [469]	validation_0-auc:0.70745
# [470]	validation_0-auc:0.70742
# [471]	validation_0-auc:0.70739
# [472]	validation_0-auc:0.70754
# [473]	validation_0-auc:0.70755
# [474]	validation_0-auc:0.70755
# [475]	validation_0-auc:0.70759
# [476]	validation_0-auc:0.70760
# [477]	validation_0-auc:0.70778
# [478]	validation_0-auc:0.70780
# [479]	validation_0-auc:0.70783
# [480]	validation_0-auc:0.70780
# [481]	validation_0-auc:0.70780
# [482]	validation_0-auc:0.70775
# [483]	validation_0-auc:0.70769
# [484]	validation_0-auc:0.70768
# [485]	validation_0-auc:0.70770
# [486]	validation_0-auc:0.70773
# [487]	validation_0-auc:0.70774
# [488]	validation_0-auc:0.70774
# [489]	validation_0-auc:0.70769
# [490]	validation_0-auc:0.70785
# [491]	validation_0-auc:0.70780
# [492]	validation_0-auc:0.70779
# [493]	validation_0-auc:0.70784
# [494]	validation_0-auc:0.70783
# [495]	validation_0-auc:0.70786
# [496]	validation_0-auc:0.70787
# [497]	validation_0-auc:0.70790
# [498]	validation_0-auc:0.70790
# [499]	validation_0-auc:0.70798
# [500]	validation_0-auc:0.70798
# [501]	validation_0-auc:0.70799
# [502]	validation_0-auc:0.70801
# [503]	validation_0-auc:0.70801
# [504]	validation_0-auc:0.70801
# [505]	validation_0-auc:0.70803
# [506]	validation_0-auc:0.70832
# [507]	validation_0-auc:0.70832
# [508]	validation_0-auc:0.70844
# [509]	validation_0-auc:0.70845
# [510]	validation_0-auc:0.70846
# [511]	validation_0-auc:0.70849
# [512]	validation_0-auc:0.70856
# [513]	validation_0-auc:0.70857
# [514]	validation_0-auc:0.70857
# [515]	validation_0-auc:0.70857
# [516]	validation_0-auc:0.70838
# [517]	validation_0-auc:0.70836
# [518]	validation_0-auc:0.70847
# [519]	validation_0-auc:0.70848
# [520]	validation_0-auc:0.70859
# [521]	validation_0-auc:0.70860
# [522]	validation_0-auc:0.70859
# [523]	validation_0-auc:0.70850
# [524]	validation_0-auc:0.70851
# [525]	validation_0-auc:0.70853
# [526]	validation_0-auc:0.70863
# [527]	validation_0-auc:0.70868
# [528]	validation_0-auc:0.70869
# [529]	validation_0-auc:0.70870
# [530]	validation_0-auc:0.70871
# [531]	validation_0-auc:0.70868
# [532]	validation_0-auc:0.70870
# [533]	validation_0-auc:0.70870
# [534]	validation_0-auc:0.70869
# [535]	validation_0-auc:0.70869
# [536]	validation_0-auc:0.70871
# [537]	validation_0-auc:0.70872
# [538]	validation_0-auc:0.70871
# [539]	validation_0-auc:0.70870
# [540]	validation_0-auc:0.70876
# [541]	validation_0-auc:0.70880
# [542]	validation_0-auc:0.70881
# [543]	validation_0-auc:0.70876
# [544]	validation_0-auc:0.70890
# [545]	validation_0-auc:0.70903
# [546]	validation_0-auc:0.70894
# [547]	validation_0-auc:0.70893
# [548]	validation_0-auc:0.70888
# [549]	validation_0-auc:0.70894
# [550]	validation_0-auc:0.70902
# [551]	validation_0-auc:0.70903
# [552]	validation_0-auc:0.70910
# [553]	validation_0-auc:0.70914
# [554]	validation_0-auc:0.70907
# [555]	validation_0-auc:0.70907
# [556]	validation_0-auc:0.70907
# [557]	validation_0-auc:0.70909
# [558]	validation_0-auc:0.70908
# [559]	validation_0-auc:0.70913
# [560]	validation_0-auc:0.70902
# [561]	validation_0-auc:0.70912
# [562]	validation_0-auc:0.70919
# [563]	validation_0-auc:0.70919
# [564]	validation_0-auc:0.70919
# [565]	validation_0-auc:0.70917
# [566]	validation_0-auc:0.70916
# [567]	validation_0-auc:0.70932
# [568]	validation_0-auc:0.70933
# [569]	validation_0-auc:0.70933
# [570]	validation_0-auc:0.70947
# [571]	validation_0-auc:0.70947
# [572]	validation_0-auc:0.70952
# [573]	validation_0-auc:0.70952
# [574]	validation_0-auc:0.70948
# [575]	validation_0-auc:0.70944
# [576]	validation_0-auc:0.70947
# [577]	validation_0-auc:0.70947
# [578]	validation_0-auc:0.70952
# [579]	validation_0-auc:0.70969
# [580]	validation_0-auc:0.70964
# [581]	validation_0-auc:0.70960
# [582]	validation_0-auc:0.70954
# [583]	validation_0-auc:0.70951
# [584]	validation_0-auc:0.70950
# [585]	validation_0-auc:0.70950
# [586]	validation_0-auc:0.70945
# [587]	validation_0-auc:0.70947
# [588]	validation_0-auc:0.70949
# [589]	validation_0-auc:0.70951
# [590]	validation_0-auc:0.70949
# [591]	validation_0-auc:0.70949
# [592]	validation_0-auc:0.70956
# [593]	validation_0-auc:0.70970
# [594]	validation_0-auc:0.70970
# [595]	validation_0-auc:0.70971
# [596]	validation_0-auc:0.70975
# [597]	validation_0-auc:0.70977
# [598]	validation_0-auc:0.70985
# [599]	validation_0-auc:0.71001
# [600]	validation_0-auc:0.71002
# [601]	validation_0-auc:0.71001
# [602]	validation_0-auc:0.71001
# [603]	validation_0-auc:0.71011
# [604]	validation_0-auc:0.71030
# [605]	validation_0-auc:0.71035
# [606]	validation_0-auc:0.71038
# [607]	validation_0-auc:0.71039
# [608]	validation_0-auc:0.71041
# [609]	validation_0-auc:0.71042
# [610]	validation_0-auc:0.71044
# [611]	validation_0-auc:0.71044
# [612]	validation_0-auc:0.71040
# [613]	validation_0-auc:0.71040
# [614]	validation_0-auc:0.71040
# [615]	validation_0-auc:0.71048
# [616]	validation_0-auc:0.71058
# [617]	validation_0-auc:0.71058
# [618]	validation_0-auc:0.71059
# [619]	validation_0-auc:0.71074
# [620]	validation_0-auc:0.71076
# [621]	validation_0-auc:0.71077
# [622]	validation_0-auc:0.71079
# [623]	validation_0-auc:0.71080
# [624]	validation_0-auc:0.71080
# [625]	validation_0-auc:0.71082
# [626]	validation_0-auc:0.71083
# [627]	validation_0-auc:0.71082
# [628]	validation_0-auc:0.71087
# [629]	validation_0-auc:0.71078
# [630]	validation_0-auc:0.71074
# [631]	validation_0-auc:0.71076
# [632]	validation_0-auc:0.71075
# [633]	validation_0-auc:0.71080
# [634]	validation_0-auc:0.71075
# [635]	validation_0-auc:0.71076
# [636]	validation_0-auc:0.71079
# [637]	validation_0-auc:0.71066
# [638]	validation_0-auc:0.71064
# [639]	validation_0-auc:0.71072
# [640]	validation_0-auc:0.71067
# [641]	validation_0-auc:0.71068
# [642]	validation_0-auc:0.71066
# [643]	validation_0-auc:0.71066
# [644]	validation_0-auc:0.71067
# [645]	validation_0-auc:0.71081
# [646]	validation_0-auc:0.71083
# [647]	validation_0-auc:0.71089
# [648]	validation_0-auc:0.71088
# [649]	validation_0-auc:0.71100
# [650]	validation_0-auc:0.71097
# [651]	validation_0-auc:0.71099
# [652]	validation_0-auc:0.71095
# [653]	validation_0-auc:0.71095
# [654]	validation_0-auc:0.71095
# [655]	validation_0-auc:0.71097
# [656]	validation_0-auc:0.71101
# [657]	validation_0-auc:0.71101
# [658]	validation_0-auc:0.71103
# [659]	validation_0-auc:0.71102
# [660]	validation_0-auc:0.71102
# [661]	validation_0-auc:0.71103
# [662]	validation_0-auc:0.71104
# [663]	validation_0-auc:0.71106
# [664]	validation_0-auc:0.71108
# [665]	validation_0-auc:0.71113
# [666]	validation_0-auc:0.71113
# [667]	validation_0-auc:0.71114
# [668]	validation_0-auc:0.71134
# [669]	validation_0-auc:0.71135
# [670]	validation_0-auc:0.71137
# [671]	validation_0-auc:0.71137
# [672]	validation_0-auc:0.71137
# [673]	validation_0-auc:0.71136
# [674]	validation_0-auc:0.71138
# [675]	validation_0-auc:0.71138
# [676]	validation_0-auc:0.71138
# [677]	validation_0-auc:0.71143
# [678]	validation_0-auc:0.71144
# [679]	validation_0-auc:0.71145
# [680]	validation_0-auc:0.71142
# [681]	validation_0-auc:0.71142
# [682]	validation_0-auc:0.71142
# [683]	validation_0-auc:0.71141
# [684]	validation_0-auc:0.71142
# [685]	validation_0-auc:0.71142
# [686]	validation_0-auc:0.71146
# [687]	validation_0-auc:0.71147
# [688]	validation_0-auc:0.71147
# [689]	validation_0-auc:0.71147
# [690]	validation_0-auc:0.71149
# [691]	validation_0-auc:0.71148
# [692]	validation_0-auc:0.71148
# [693]	validation_0-auc:0.71149
# [694]	validation_0-auc:0.71150
# [695]	validation_0-auc:0.71150
# [696]	validation_0-auc:0.71149
# [697]	validation_0-auc:0.71149
# [698]	validation_0-auc:0.71149
# [699]	validation_0-auc:0.71146
# [700]	validation_0-auc:0.71142
# [701]	validation_0-auc:0.71139
# [702]	validation_0-auc:0.71139
# [703]	validation_0-auc:0.71149
# [704]	validation_0-auc:0.71154
# [705]	validation_0-auc:0.71154
# [706]	validation_0-auc:0.71153
# [707]	validation_0-auc:0.71153
# [708]	validation_0-auc:0.71153
# [709]	validation_0-auc:0.71153
# [710]	validation_0-auc:0.71144
# [711]	validation_0-auc:0.71147
# [712]	validation_0-auc:0.71144
# [713]	validation_0-auc:0.71145
# [714]	validation_0-auc:0.71150
# [715]	validation_0-auc:0.71149
# [716]	validation_0-auc:0.71143
# [717]	validation_0-auc:0.71164
# [718]	validation_0-auc:0.71171
# [719]	validation_0-auc:0.71168
# [720]	validation_0-auc:0.71169
# [721]	validation_0-auc:0.71162
# [722]	validation_0-auc:0.71163
# [723]	validation_0-auc:0.71162
# [724]	validation_0-auc:0.71165
# [725]	validation_0-auc:0.71174
# [726]	validation_0-auc:0.71169
# [727]	validation_0-auc:0.71165
# [728]	validation_0-auc:0.71169
# [729]	validation_0-auc:0.71169
# [730]	validation_0-auc:0.71173
# [731]	validation_0-auc:0.71172
# [732]	validation_0-auc:0.71175
# [733]	validation_0-auc:0.71174
# [734]	validation_0-auc:0.71174
# [735]	validation_0-auc:0.71171
# [736]	validation_0-auc:0.71168
# [737]	validation_0-auc:0.71165
# [738]	validation_0-auc:0.71172
# [739]	validation_0-auc:0.71174
# [740]	validation_0-auc:0.71168
# [741]	validation_0-auc:0.71169
# [742]	validation_0-auc:0.71181
# [743]	validation_0-auc:0.71185
# [744]	validation_0-auc:0.71185
# [745]	validation_0-auc:0.71180
# [746]	validation_0-auc:0.71177
# [747]	validation_0-auc:0.71210
# [748]	validation_0-auc:0.71216
# [749]	validation_0-auc:0.71213
# [750]	validation_0-auc:0.71217
# [751]	validation_0-auc:0.71217
# [752]	validation_0-auc:0.71225
# [753]	validation_0-auc:0.71237
# [754]	validation_0-auc:0.71249
# [755]	validation_0-auc:0.71249
# [756]	validation_0-auc:0.71259
# [757]	validation_0-auc:0.71265
# [758]	validation_0-auc:0.71265
# [759]	validation_0-auc:0.71260
# [760]	validation_0-auc:0.71269
# [761]	validation_0-auc:0.71268
# [762]	validation_0-auc:0.71265
# [763]	validation_0-auc:0.71264
# [764]	validation_0-auc:0.71277
# [765]	validation_0-auc:0.71272
# [766]	validation_0-auc:0.71267
# [767]	validation_0-auc:0.71267
# [768]	validation_0-auc:0.71266
# [769]	validation_0-auc:0.71295
# [770]	validation_0-auc:0.71294
# [771]	validation_0-auc:0.71290
# [772]	validation_0-auc:0.71290
# [773]	validation_0-auc:0.71297
# [774]	validation_0-auc:0.71299
# [775]	validation_0-auc:0.71305
# [776]	validation_0-auc:0.71302
# [777]	validation_0-auc:0.71301
# [778]	validation_0-auc:0.71305
# [779]	validation_0-auc:0.71306
# [780]	validation_0-auc:0.71306
# [781]	validation_0-auc:0.71306
# [782]	validation_0-auc:0.71305
# [783]	validation_0-auc:0.71306
# [784]	validation_0-auc:0.71319
# [785]	validation_0-auc:0.71318
# [786]	validation_0-auc:0.71319
# [787]	validation_0-auc:0.71328
# [788]	validation_0-auc:0.71318
# [789]	validation_0-auc:0.71311
# [790]	validation_0-auc:0.71311
# [791]	validation_0-auc:0.71308
# [792]	validation_0-auc:0.71308
# [793]	validation_0-auc:0.71308
# [794]	validation_0-auc:0.71309
# [795]	validation_0-auc:0.71306
# [796]	validation_0-auc:0.71318
# [797]	validation_0-auc:0.71315
# [798]	validation_0-auc:0.71311
# [799]	validation_0-auc:0.71311
# [800]	validation_0-auc:0.71311
# [801]	validation_0-auc:0.71311
# [802]	validation_0-auc:0.71303
# [803]	validation_0-auc:0.71304
# [804]	validation_0-auc:0.71311
# [805]	validation_0-auc:0.71309
# [806]	validation_0-auc:0.71311
# [807]	validation_0-auc:0.71307
# [808]	validation_0-auc:0.71309
# [809]	validation_0-auc:0.71313
# [810]	validation_0-auc:0.71313
# [811]	validation_0-auc:0.71314
# [812]	validation_0-auc:0.71299
# [813]	validation_0-auc:0.71303
# [814]	validation_0-auc:0.71303
# [815]	validation_0-auc:0.71298
# [816]	validation_0-auc:0.71307
# [817]	validation_0-auc:0.71309
# [818]	validation_0-auc:0.71312
# [819]	validation_0-auc:0.71312
# [820]	validation_0-auc:0.71312
# [821]	validation_0-auc:0.71316
# [822]	validation_0-auc:0.71319
# [823]	validation_0-auc:0.71315
# [824]	validation_0-auc:0.71322
# [825]	validation_0-auc:0.71319
# [826]	validation_0-auc:0.71320
# [827]	validation_0-auc:0.71318
# [828]	validation_0-auc:0.71330
# [829]	validation_0-auc:0.71338
# [830]	validation_0-auc:0.71347
# [831]	validation_0-auc:0.71344
# [832]	validation_0-auc:0.71344
# [833]	validation_0-auc:0.71346
# [834]	validation_0-auc:0.71349
# [835]	validation_0-auc:0.71359
# [836]	validation_0-auc:0.71360
# [837]	validation_0-auc:0.71360
# [838]	validation_0-auc:0.71359
# [839]	validation_0-auc:0.71359
# [840]	validation_0-auc:0.71364
# [841]	validation_0-auc:0.71364
# [842]	validation_0-auc:0.71363
# [843]	validation_0-auc:0.71368
# [844]	validation_0-auc:0.71365
# [845]	validation_0-auc:0.71384
# [846]	validation_0-auc:0.71390
# [847]	validation_0-auc:0.71393
# [848]	validation_0-auc:0.71391
# [849]	validation_0-auc:0.71390
# [850]	validation_0-auc:0.71395
# [851]	validation_0-auc:0.71397
# [852]	validation_0-auc:0.71395
# [853]	validation_0-auc:0.71396
# [854]	validation_0-auc:0.71388
# [855]	validation_0-auc:0.71390
# [856]	validation_0-auc:0.71391
# [857]	validation_0-auc:0.71391
# [858]	validation_0-auc:0.71390
# [859]	validation_0-auc:0.71390
# [860]	validation_0-auc:0.71390
# [861]	validation_0-auc:0.71390
# [862]	validation_0-auc:0.71390
# [863]	validation_0-auc:0.71406
# [864]	validation_0-auc:0.71397
# [865]	validation_0-auc:0.71400
# [866]	validation_0-auc:0.71394
# [867]	validation_0-auc:0.71395
# [868]	validation_0-auc:0.71389
# [869]	validation_0-auc:0.71396
# [870]	validation_0-auc:0.71398
# [871]	validation_0-auc:0.71410
# [872]	validation_0-auc:0.71414
# [873]	validation_0-auc:0.71415
# [874]	validation_0-auc:0.71419
# [875]	validation_0-auc:0.71415
# [876]	validation_0-auc:0.71415
# [877]	validation_0-auc:0.71415
# [878]	validation_0-auc:0.71422
# [879]	validation_0-auc:0.71423
# [880]	validation_0-auc:0.71415
# [881]	validation_0-auc:0.71415
# [882]	validation_0-auc:0.71412
# [883]	validation_0-auc:0.71411
# [884]	validation_0-auc:0.71421
# [885]	validation_0-auc:0.71416
# [886]	validation_0-auc:0.71416
# [887]	validation_0-auc:0.71421
# [888]	validation_0-auc:0.71421
# [889]	validation_0-auc:0.71413
# [890]	validation_0-auc:0.71427
# [891]	validation_0-auc:0.71431
# [892]	validation_0-auc:0.71431
# [893]	validation_0-auc:0.71430
# [894]	validation_0-auc:0.71433
# [895]	validation_0-auc:0.71447
# [896]	validation_0-auc:0.71447
# [897]	validation_0-auc:0.71449
# [898]	validation_0-auc:0.71454
# [899]	validation_0-auc:0.71454
# [900]	validation_0-auc:0.71455
# [901]	validation_0-auc:0.71466
# [902]	validation_0-auc:0.71466
# [903]	validation_0-auc:0.71469
# [904]	validation_0-auc:0.71469
# [905]	validation_0-auc:0.71471
# [906]	validation_0-auc:0.71471
# [907]	validation_0-auc:0.71462
# [908]	validation_0-auc:0.71461
# [909]	validation_0-auc:0.71456
# [910]	validation_0-auc:0.71450
# [911]	validation_0-auc:0.71447
# [912]	validation_0-auc:0.71446
# [913]	validation_0-auc:0.71446
# [914]	validation_0-auc:0.71442
# [915]	validation_0-auc:0.71446
# [916]	validation_0-auc:0.71445
# [917]	validation_0-auc:0.71448
# [918]	validation_0-auc:0.71445
# [919]	validation_0-auc:0.71445
# [920]	validation_0-auc:0.71446
# [921]	validation_0-auc:0.71462
# [922]	validation_0-auc:0.71455
# [923]	validation_0-auc:0.71458
# [924]	validation_0-auc:0.71460
# [925]	validation_0-auc:0.71466
# [926]	validation_0-auc:0.71467
# [927]	validation_0-auc:0.71471
# [928]	validation_0-auc:0.71471
# [929]	validation_0-auc:0.71471
# [930]	validation_0-auc:0.71476
# [931]	validation_0-auc:0.71474
# [932]	validation_0-auc:0.71475
# [933]	validation_0-auc:0.71476
# [934]	validation_0-auc:0.71480
# [935]	validation_0-auc:0.71481
# [936]	validation_0-auc:0.71481
# [937]	validation_0-auc:0.71477
# [938]	validation_0-auc:0.71476
# [939]	validation_0-auc:0.71478
# [940]	validation_0-auc:0.71472
# [941]	validation_0-auc:0.71472
# [942]	validation_0-auc:0.71469
# [943]	validation_0-auc:0.71467
# [944]	validation_0-auc:0.71477
# [945]	validation_0-auc:0.71477
# [946]	validation_0-auc:0.71477
# [947]	validation_0-auc:0.71469
# [948]	validation_0-auc:0.71464
# [949]	validation_0-auc:0.71468
# [950]	validation_0-auc:0.71468
# [951]	validation_0-auc:0.71467
# [952]	validation_0-auc:0.71468
# [953]	validation_0-auc:0.71468
# [954]	validation_0-auc:0.71472
# [955]	validation_0-auc:0.71475
# [956]	validation_0-auc:0.71475
# [957]	validation_0-auc:0.71476
# [958]	validation_0-auc:0.71475
# [959]	validation_0-auc:0.71476
# [960]	validation_0-auc:0.71468
# [961]	validation_0-auc:0.71499
# [962]	validation_0-auc:0.71501
# [963]	validation_0-auc:0.71501
# [964]	validation_0-auc:0.71499
# [965]	validation_0-auc:0.71499
# [966]	validation_0-auc:0.71497
# [967]	validation_0-auc:0.71498
# [968]	validation_0-auc:0.71497
# [969]	validation_0-auc:0.71504
# [970]	validation_0-auc:0.71505
# [971]	validation_0-auc:0.71512
# [972]	validation_0-auc:0.71506
# [973]	validation_0-auc:0.71506
# [974]	validation_0-auc:0.71506
# [975]	validation_0-auc:0.71506
# [976]	validation_0-auc:0.71506
# [977]	validation_0-auc:0.71505
# [978]	validation_0-auc:0.71505
# [1382]	validation_0-auc:0.71932
# [1383]	validation_0-auc:0.71932
# [1384]	validation_0-auc:0.71927
# [1385]	validation_0-auc:0.71937
# [1386]	validation_0-auc:0.71950
# [1387]	validation_0-auc:0.71960
# [1388]	validation_0-auc:0.71960
# [1389]	validation_0-auc:0.71962
# [1390]	validation_0-auc:0.71962
# [1391]	validation_0-auc:0.71961
# [1392]	validation_0-auc:0.71955
# [1393]	validation_0-auc:0.71956
# [1394]	validation_0-auc:0.71967
# [1395]	validation_0-auc:0.71967
# [1396]	validation_0-auc:0.71965
# [1397]	validation_0-auc:0.71966
# [1398]	validation_0-auc:0.71964
# [1399]	validation_0-auc:0.71967
# [1400]	validation_0-auc:0.71977
# [1401]	validation_0-auc:0.71978
# [1402]	validation_0-auc:0.71982
# [1403]	validation_0-auc:0.71988
# [1404]	validation_0-auc:0.71987
# [1405]	validation_0-auc:0.71992
# [1406]	validation_0-auc:0.71996
# [1407]	validation_0-auc:0.72014
# [1408]	validation_0-auc:0.72014
# [1409]	validation_0-auc:0.72015
# [1410]	validation_0-auc:0.72015
# [1411]	validation_0-auc:0.72014
# [1412]	validation_0-auc:0.72012
# [1413]	validation_0-auc:0.72027
# [1414]	validation_0-auc:0.72028
# [1415]	validation_0-auc:0.72025
# [1416]	validation_0-auc:0.72026
# [1417]	validation_0-auc:0.72025
# [1418]	validation_0-auc:0.72025
# [1419]	validation_0-auc:0.72026
# [1420]	validation_0-auc:0.72028
# [1421]	validation_0-auc:0.72025
# [1422]	validation_0-auc:0.72023
# [1423]	validation_0-auc:0.72024
# [1424]	validation_0-auc:0.72029
# [1425]	validation_0-auc:0.72030
# [1426]	validation_0-auc:0.72029
# [1427]	validation_0-auc:0.72029
# [1428]	validation_0-auc:0.72029
# [1429]	validation_0-auc:0.72032
# [1430]	validation_0-auc:0.72037
# [1431]	validation_0-auc:0.72040
# [1432]	validation_0-auc:0.72041
# [1433]	validation_0-auc:0.72037
# [1434]	validation_0-auc:0.72045
# [1435]	validation_0-auc:0.72039
# [1436]	validation_0-auc:0.72046
# [1437]	validation_0-auc:0.72047
# [1438]	validation_0-auc:0.72047
# [1439]	validation_0-auc:0.72046
# [1440]	validation_0-auc:0.72041
# [1441]	validation_0-auc:0.72041
# [1442]	validation_0-auc:0.72038
# [1443]	validation_0-auc:0.72041
# [1444]	validation_0-auc:0.72042
# [1445]	validation_0-auc:0.72044
# [1446]	validation_0-auc:0.72049
# [1447]	validation_0-auc:0.72047
# [1448]	validation_0-auc:0.72041
# [1449]	validation_0-auc:0.72039
# [1450]	validation_0-auc:0.72034
# [1451]	validation_0-auc:0.72030
# [1452]	validation_0-auc:0.72031
# [1453]	validation_0-auc:0.72027
# [1454]	validation_0-auc:0.72027
# [1455]	validation_0-auc:0.72026
# [1456]	validation_0-auc:0.72024
# [1457]	validation_0-auc:0.72024
# [1458]	validation_0-auc:0.72025
# [1459]	validation_0-auc:0.72025
# [1460]	validation_0-auc:0.72027
# [1461]	validation_0-auc:0.72031
# [1462]	validation_0-auc:0.72022
# [1463]	validation_0-auc:0.72028
# [1464]	validation_0-auc:0.72024
# [1465]	validation_0-auc:0.72024
# [1466]	validation_0-auc:0.72023
# [1467]	validation_0-auc:0.72024
# [1468]	validation_0-auc:0.72023
# [1469]	validation_0-auc:0.72024
# [1470]	validation_0-auc:0.72025
# [1471]	validation_0-auc:0.72018
# [1472]	validation_0-auc:0.72022
# [1473]	validation_0-auc:0.72022
# [1474]	validation_0-auc:0.72024
# [1475]	validation_0-auc:0.72023
# [1476]	validation_0-auc:0.72023
# [1477]	validation_0-auc:0.72023
# [1478]	validation_0-auc:0.72027
# [1479]	validation_0-auc:0.72027
# [1480]	validation_0-auc:0.72026
# [1481]	validation_0-auc:0.72026
# [1482]	validation_0-auc:0.72029
# [1483]	validation_0-auc:0.72033
# [1484]	validation_0-auc:0.72034
# [1485]	validation_0-auc:0.72034
# [1486]	validation_0-auc:0.72034
# [1487]	validation_0-auc:0.72038
# [1488]	validation_0-auc:0.72040
# [1489]	validation_0-auc:0.72041
# [1490]	validation_0-auc:0.72040
# [1491]	validation_0-auc:0.72039
# [1492]	validation_0-auc:0.72041
# [1493]	validation_0-auc:0.72040
# [1494]	validation_0-auc:0.72041
# [1495]	validation_0-auc:0.72049
# [1496]	validation_0-auc:0.72046
# [1497]	validation_0-auc:0.72054
# [1498]	validation_0-auc:0.72056
# [1499]	validation_0-auc:0.72055
# [1500]	validation_0-auc:0.72058
# [1501]	validation_0-auc:0.72046
# [1502]	validation_0-auc:0.72049
# [1503]	validation_0-auc:0.72048
# [1504]	validation_0-auc:0.72048
# [1505]	validation_0-auc:0.72050
# [1506]	validation_0-auc:0.72051
# [1507]	validation_0-auc:0.72052
# [1508]	validation_0-auc:0.72056
# [1509]	validation_0-auc:0.72057
# [1510]	validation_0-auc:0.72056
# [1511]	validation_0-auc:0.72056
# [1512]	validation_0-auc:0.72061
# [1513]	validation_0-auc:0.72066
# [1514]	validation_0-auc:0.72064
# [1515]	validation_0-auc:0.72064
# [1516]	validation_0-auc:0.72058
# [1517]	validation_0-auc:0.72058
# [1518]	validation_0-auc:0.72061
# [1519]	validation_0-auc:0.72061
# [1520]	validation_0-auc:0.72062
# [1521]	validation_0-auc:0.72061
# [1522]	validation_0-auc:0.72067
# [1523]	validation_0-auc:0.72064
# [1524]	validation_0-auc:0.72064
# [1525]	validation_0-auc:0.72069
# [1526]	validation_0-auc:0.72069
# [1527]	validation_0-auc:0.72064
# [1528]	validation_0-auc:0.72067
# [1529]	validation_0-auc:0.72070
# [1530]	validation_0-auc:0.72071
# [1531]	validation_0-auc:0.72070
# [1532]	validation_0-auc:0.72070
# [1533]	validation_0-auc:0.72062
# [1534]	validation_0-auc:0.72065
# [1535]	validation_0-auc:0.72061
# [1536]	validation_0-auc:0.72062
# [1537]	validation_0-auc:0.72062
# [1538]	validation_0-auc:0.72055
# [1539]	validation_0-auc:0.72071
# [1540]	validation_0-auc:0.72081
# [1541]	validation_0-auc:0.72083
# [1542]	validation_0-auc:0.72084
# [1543]	validation_0-auc:0.72077
# [1544]	validation_0-auc:0.72078
# [1545]	validation_0-auc:0.72080
# [1546]	validation_0-auc:0.72079
# [1547]	validation_0-auc:0.72078
# [1548]	validation_0-auc:0.72080
# [1549]	validation_0-auc:0.72083
# [1550]	validation_0-auc:0.72090
# [1551]	validation_0-auc:0.72091
# [1552]	validation_0-auc:0.72095
# [1553]	validation_0-auc:0.72100
# [1554]	validation_0-auc:0.72101
# [1555]	validation_0-auc:0.72099
# [1556]	validation_0-auc:0.72099
# [1557]	validation_0-auc:0.72096
# [1558]	validation_0-auc:0.72096
# [1559]	validation_0-auc:0.72101
# [1560]	validation_0-auc:0.72100
# [1561]	validation_0-auc:0.72110
# [1562]	validation_0-auc:0.72109
# [1563]	validation_0-auc:0.72128
# [1564]	validation_0-auc:0.72124
# [1565]	validation_0-auc:0.72125
# [1566]	validation_0-auc:0.72123
# [1567]	validation_0-auc:0.72124
# [1568]	validation_0-auc:0.72124
# [1569]	validation_0-auc:0.72124
# [1570]	validation_0-auc:0.72124
# [1571]	validation_0-auc:0.72126
# [1572]	validation_0-auc:0.72129
# [1573]	validation_0-auc:0.72129
# [1574]	validation_0-auc:0.72123
# [1575]	validation_0-auc:0.72123
# [1576]	validation_0-auc:0.72123
# [1577]	validation_0-auc:0.72117
# [1578]	validation_0-auc:0.72105
# [1579]	validation_0-auc:0.72098
# [1580]	validation_0-auc:0.72092
# [1581]	validation_0-auc:0.72091
# [1582]	validation_0-auc:0.72089
# [1583]	validation_0-auc:0.72088
# [1584]	validation_0-auc:0.72091
# [1585]	validation_0-auc:0.72091
# [1586]	validation_0-auc:0.72094
# [1587]	validation_0-auc:0.72105
# [1588]	validation_0-auc:0.72105
# [1589]	validation_0-auc:0.72105
# [1590]	validation_0-auc:0.72105
# [1591]	validation_0-auc:0.72109
# [1592]	validation_0-auc:0.72112
# [1593]	validation_0-auc:0.72112
# [1594]	validation_0-auc:0.72108
# [1595]	validation_0-auc:0.72106
# [1596]	validation_0-auc:0.72107
# [1597]	validation_0-auc:0.72105
# [1598]	validation_0-auc:0.72103
# [1599]	validation_0-auc:0.72106
# [1600]	validation_0-auc:0.72104
# [1601]	validation_0-auc:0.72104
# [1602]	validation_0-auc:0.72106
# [1603]	validation_0-auc:0.72103
# [1604]	validation_0-auc:0.72113
# [1605]	validation_0-auc:0.72114
# [1606]	validation_0-auc:0.72113
# [1607]	validation_0-auc:0.72115
# [1608]	validation_0-auc:0.72115
# [1609]	validation_0-auc:0.72112
# [1610]	validation_0-auc:0.72112
# [1611]	validation_0-auc:0.72111
# [1612]	validation_0-auc:0.72109
# [1613]	validation_0-auc:0.72124
# [1614]	validation_0-auc:0.72125
# [1615]	validation_0-auc:0.72126
# [1616]	validation_0-auc:0.72128
# [1617]	validation_0-auc:0.72127
# [1618]	validation_0-auc:0.72127
# [1619]	validation_0-auc:0.72129
# [1620]	validation_0-auc:0.72128
# [1621]	validation_0-auc:0.72132
# [1622]	validation_0-auc:0.72129
# [1623]	validation_0-auc:0.72129
# [1624]	validation_0-auc:0.72129
# [1625]	validation_0-auc:0.72131
# [1626]	validation_0-auc:0.72134
# [1627]	validation_0-auc:0.72121
# [1628]	validation_0-auc:0.72125
# [1629]	validation_0-auc:0.72125
# [1630]	validation_0-auc:0.72123
# [1631]	validation_0-auc:0.72124
# [1632]	validation_0-auc:0.72129
# [1633]	validation_0-auc:0.72126
# [1634]	validation_0-auc:0.72121
# [1635]	validation_0-auc:0.72122
# [1636]	validation_0-auc:0.72099
# [1637]	validation_0-auc:0.72094
# [1638]	validation_0-auc:0.72094
# [1639]	validation_0-auc:0.72093
# [1640]	validation_0-auc:0.72088
# [1641]	validation_0-auc:0.72083
# [1642]	validation_0-auc:0.72083
# [1643]	validation_0-auc:0.72095
# [1644]	validation_0-auc:0.72100
# [1645]	validation_0-auc:0.72106
# [1646]	validation_0-auc:0.72106
# [1647]	validation_0-auc:0.72104
# [1648]	validation_0-auc:0.72105
# [1649]	validation_0-auc:0.72103
# [1650]	validation_0-auc:0.72101
# [1651]	validation_0-auc:0.72102
# [1652]	validation_0-auc:0.72100
# [1653]	validation_0-auc:0.72103
# [1654]	validation_0-auc:0.72105
# [1655]	validation_0-auc:0.72105
# [1656]	validation_0-auc:0.72107
# [1657]	validation_0-auc:0.72104
# [1658]	validation_0-auc:0.72103
# [1659]	validation_0-auc:0.72104
# [1660]	validation_0-auc:0.72103
# [1661]	validation_0-auc:0.72102
# [1662]	validation_0-auc:0.72101
# [1663]	validation_0-auc:0.72101
# [1664]	validation_0-auc:0.72103
# [1665]	validation_0-auc:0.72103
# [1666]	validation_0-auc:0.72108
# [1667]	validation_0-auc:0.72095
# [1668]	validation_0-auc:0.72091
# [1669]	validation_0-auc:0.72091
# [1670]	validation_0-auc:0.72091
# [1671]	validation_0-auc:0.72089
# [1672]	validation_0-auc:0.72089
# [1673]	validation_0-auc:0.72089
# [1674]	validation_0-auc:0.72085
# [1675]	validation_0-auc:0.72081
# [1676]	validation_0-auc:0.72080
# [1677]	validation_0-auc:0.72078
# [1678]	validation_0-auc:0.72078
# [1679]	validation_0-auc:0.72077
# [1680]	validation_0-auc:0.72077
# [1681]	validation_0-auc:0.72076
# [1682]	validation_0-auc:0.72076
# [1683]	validation_0-auc:0.72061
# [1684]	validation_0-auc:0.72061
# [1685]	validation_0-auc:0.72056
# [1686]	validation_0-auc:0.72056
# [1687]	validation_0-auc:0.72050
# [1688]	validation_0-auc:0.72048
# [1689]	validation_0-auc:0.72046
# [1690]	validation_0-auc:0.72045
# [1691]	validation_0-auc:0.72044
# [1692]	validation_0-auc:0.72041
# [1693]	validation_0-auc:0.72042
# [1694]	validation_0-auc:0.72041
# [1695]	validation_0-auc:0.72042
# [1696]	validation_0-auc:0.72042
# [1697]	validation_0-auc:0.72036
# [1698]	validation_0-auc:0.72039
# [1699]	validation_0-auc:0.72049
# [1700]	validation_0-auc:0.72052
# [1701]	validation_0-auc:0.72049
# [1702]	validation_0-auc:0.72048
# [1703]	validation_0-auc:0.72052
# [1704]	validation_0-auc:0.72052
# [1705]	validation_0-auc:0.72051
# [1706]	validation_0-auc:0.72049
# [1707]	validation_0-auc:0.72050
# [1708]	validation_0-auc:0.72054
# [1709]	validation_0-auc:0.72056
# [1710]	validation_0-auc:0.72051
# [1711]	validation_0-auc:0.72052
# [1712]	validation_0-auc:0.72054
# [1713]	validation_0-auc:0.72051
# [1714]	validation_0-auc:0.72051
# [1715]	validation_0-auc:0.72051
# [1716]	validation_0-auc:0.72051
# [1717]	validation_0-auc:0.72050
# [1718]	validation_0-auc:0.72053
# [1719]	validation_0-auc:0.72055
# [1720]	validation_0-auc:0.72055
# [1721]	validation_0-auc:0.72060
# [1722]	validation_0-auc:0.72065
# [1723]	validation_0-auc:0.72064
# [1724]	validation_0-auc:0.72063
# [1725]	validation_0-auc:0.72063
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=100, enable_categorical=False,
#               eval_metric='auc', gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=12, max_leaves=5, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=2000,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=42,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
print("train ACC :", xg.score(train_xg_X, train_xg_y))
print("test ACC :", xg.score(test_xg_X, test_xg_y))

pred = xg.predict_proba(test_xg_X)[:,1]
print("test AUC :", roc_auc_score(test_xg_y, pred))
# Out:
# train ACC : 0.7965766040715653
# test ACC : 0.6407158836689038
# test AUC : 0.7213415503277563

# %%
print("train ACC :", xg.score(X_train_rf, y_train_rf))
print("test ACC :", xg.score(X_test_rf, y_test_rf))

pred = xg.predict_proba(X_test_rf)[:,1]
print("test AUC :", roc_auc_score(y_test_rf, pred))
# Out:
# train ACC : 0.7770050067469044
# test ACC : 0.6218236173393124
# test AUC : 0.6997530312065194

# %%
infer_xgc = xg.predict_proba(df_infer_xg)[:, 1]
infer_xgc[:10]
# Out:
# array([0.7496511 , 0.6661245 , 0.48368952, 0.97167146, 0.4896818 ,
#        0.86565614, 0.675887  , 0.4423526 , 0.26797757, 0.8934992 ],
#       dtype=float32)

# %%
print("infer set 평균, 최대값, 최소값")
print(infer_xgc.mean())
print(infer_xgc.max())
print(infer_xgc.min())
# Out:
# infer set 평균, 최대값, 최소값
# 0.5839226
# 0.9801948
# 0.029627837

# %%
xg_output = pd.read_csv("cbc.csv")
xg_output['prediction'] = infer_xgc
xg_output
# Out:
#       id  prediction
# 0      0    0.749651
# 1      1    0.666125
# 2      2    0.483690
# 3      3    0.971671
# 4      4    0.489682
# ..   ...         ...
# 739  739    0.449469
# 740  740    0.733220
# 741  741    0.803654
# 742  742    0.408220
# 743  743    0.563905
#
# [744 rows x 2 columns]

# %%
xg_output.to_csv('xgbc.csv', index=False)

# %%
cb_output = pd.read_csv("catboost.csv")
cb_output
# Out:
#       id  prediction
# 0      0    0.590133
# 1      1    0.695980
# 2      2    0.467011
# 3      3    0.651939
# 4      4    0.371707
# ..   ...         ...
# 739  739    0.240993
# 740  740    0.830760
# 741  741    0.751222
# 742  742    0.554715
# 743  743    0.587887
#
# [744 rows x 2 columns]

# %%
temp = (infer_xgc + cb_output['prediction']) / 2
cb_output['prediction'] = temp
cb_output.to_csv('cb_xg.csv', index=False)
